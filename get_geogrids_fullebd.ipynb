# %%
#import fireducks.pandas as pd
import pandas as pd
import pandas as pdr

from pathlib import Path
import h3
import folium
from geojson import Feature, FeatureCollection
import _json
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import ast
pd.options.mode.copy_on_write = True 
from functools import reduce
from folium import GeoJsonTooltip
import json
import cProfile
import pstats

from progiter import ProgIter

# %% [markdown]
# NOTE: Length of Oct2024 eBird dataset in rows: 1.75 billion records

# %% [markdown]
# ## Create JSON of subspecies

# %%
# Load eBird taxonomy
taxonomy = pd.read_csv("eBird_taxonomy_v2024.csv")
taxonomy.head()
# Out:
#    TAXON_ORDER CATEGORY SPECIES_CODE  TAXON_CONCEPT_ID       PRIMARY_COM_NAME  \
# 0            2  species      ostric2               NaN         Common Ostrich
# 1            7  species      ostric3               NaN         Somali Ostrich
# 2            8    slash       y00934               NaN  Common/Somali Ostrich
# 3           10  species      soucas1               NaN     Southern Cassowary
# 4           11  species      dwacas1               NaN        Dwarf Cassowary
#
#                          SCI_NAME             ORDER  \
# 0                Struthio camelus  Struthioniformes
# 1          Struthio molybdophanes  Struthioniformes
# 2  Struthio camelus/molybdophanes  Struthioniformes
# 3             Casuarius casuarius    Casuariiformes
# 4              Casuarius bennetti    Casuariiformes
#
#                               FAMILY        SPECIES_GROUP REPORT_AS
# 0          Struthionidae (Ostriches)            Ostriches       NaN
# 1          Struthionidae (Ostriches)            Ostriches       NaN
# 2          Struthionidae (Ostriches)            Ostriches       NaN
# 3  Casuariidae (Cassowaries and Emu)  Cassowaries and Emu       NaN
# 4  Casuariidae (Cassowaries and Emu)  Cassowaries and Emu       NaN

# %%
taxonomy.CATEGORY
# Out:
# 0        species
# 1        species
# 2          slash
# 3        species
# 4        species
#           ...
# 17410    species
# 17411       spuh
# 17412       spuh
# 17413       spuh
# 17414       spuh
# Name: CATEGORY, Length: 17415, dtype: object

# %%
# What categories are there in the taxonomy?
taxonomy.CATEGORY.unique()
# Out:
# array(['species', 'slash', 'issf', 'hybrid', 'spuh', 'domestic', 'form',
#        'intergrade'], dtype=object)

# %%
# How many species are there?
species = taxonomy[taxonomy.CATEGORY == 'species']
len(species)
# Out:
# 11145

# %%
# How many infraspecific entries are there?
infrasp_categories = ['issf', 'form', 'intergrade']
infraspp = taxonomy[taxonomy.CATEGORY.isin(infrasp_categories)]
len(infraspp)
# Out:
# 3843

# %%
# Create a dictionary mapping species to their infraspecies, by category
# Most species have a single category of infraspecies (e.g. either form or subspecies, not both)
# However some species have infraspecies in multiple categories, e.g. Brant (Branta bernicla) has both subspecies and forms
spp_dict = species[['SPECIES_CODE', 'PRIMARY_COM_NAME', 'SCI_NAME']].set_index("SCI_NAME").T.to_dict()
# Add infraspecies to spp_json
#for sp in tqdm(spp_dict.keys()):
for sp in spp_dict.keys():
    # Get infraspecies for this species
    infraspp_for_sp = infraspp[infraspp['SCI_NAME'].apply(lambda x: x[:len(sp)] == sp)]
    infraspp_dict = dict()

    # Add infraspecies to spp_json by category
    for cat in infrasp_categories:
        infrasp_in_category = infraspp_for_sp[infraspp_for_sp.CATEGORY == cat]
        infrasp_cat_dict = infrasp_in_category[
            ['SPECIES_CODE', 'PRIMARY_COM_NAME', 'SCI_NAME']].set_index("SCI_NAME").T.to_dict()
        if len(infrasp_cat_dict.keys()) > 0:
            infraspp_dict[cat] = infrasp_cat_dict
    spp_dict[sp]['infraspecies'] = infraspp_dict

# %%
with open("infraspecies_ebird.json", 'w') as f:
    f.write(json.dumps(spp_dict, indent=4))

# %%
with open("infraspecies_ebird.json") as f:
    spp_dict = json.load(f)

# %% [markdown]
# ## Prep eBird data

# %% [markdown]
# Use the following H3 resolutions:
# ```
# Res	Average Hexagon Area (km2)	Pentagon Area* (km2)	Ratio (P/H)
# 2	86,801.780398997	44,930.898497879	0.5176
# 3	12,393.434655088	6,315.472267516	0.5096
# 4	1,770.347654491	896.582383141	0.5064
# ```
#
# They have this many cells:
# ```
# Res	Total number of cells	Number of hexagons	Number of pentagons
# 2	5,882	5,870	12
# 3	41,162	41,150	12
# 4	288,122	288,110	12
# ```

# %%
resolutions = [2, 3, 4]

# %% [markdown]
# ## Determine number of sightings of each subspecies per grid cell

# %% [markdown]
# ### Calculate in batches

# %%
from perc import Perc

import time

# %%
filter_by_status(chunk, status="unflagged")
# Out:
#           SCIENTIFIC NAME SUBSPECIES SCIENTIFIC NAME   LATITUDE   LONGITUDE  \
# 0       Buteo jamaicensis                             40.970318 -105.091618
# 1       Buteo jamaicensis                             40.537425 -105.000866
# 2       Buteo jamaicensis                             40.373050 -105.614061
# 3       Buteo jamaicensis                             40.546809 -105.018439
# 4       Buteo jamaicensis                             40.865712 -105.322842
# ...                   ...                        ...        ...         ...
# 499994  Buteo jamaicensis                             33.910208  -84.322343
# 499995  Buteo jamaicensis                             33.815331  -84.301474
# 499996  Buteo jamaicensis                             33.812814  -84.155273
# 499997  Buteo jamaicensis                             33.812814  -84.155273
# 499998  Buteo jamaicensis                             33.901406  -84.338184
#
#        OBSERVATION DATE SAMPLING EVENT IDENTIFIER GROUP IDENTIFIER APPROVED  \
# 0            2024-06-08                S180380790                         1
# 1            2024-06-26                S184011107                         1
# 2            2024-06-22                S183775095                         1
# 3            2024-06-16                S181951563                         1
# 4            2024-06-22                S183165408                         1
# ...                 ...                       ...              ...      ...
# 499994       2018-04-17                 S44665401                         1
# 499995       2018-04-21                 S44799725                         1
# 499996       2018-04-11                 S44468192         G3084213        1
# 499997       2018-04-26                 S44963415                         1
# 499998       2018-04-21                 S44788703                         1
#
#        REVIEWED
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 499994        0
# 499995        0
# 499996        0
# 499997        0
# 499998        0
#
# [481463 rows x 9 columns]

# %% [markdown]
# ### How big to make CSVs?

# %%
# %%time
def remove_duplicates(df):
    """Remove any species sightings duplicated across groups
    
    Args:
        df: a slice of the eBird dataset in a dataframe
    """
    # Remove duplicate checklists
    return df[df['GROUP IDENTIFIER'].isnull() | ~df[df['GROUP IDENTIFIER'].notnull()].duplicated(subset=["GROUP IDENTIFIER", "SCIENTIFIC NAME"],keep='first')]

def filter_by_status(
    df,
    status='approved' #otherwise: unflagged, flagged_approved, unconfirmed
):
    """Filter eBird records by flag and approval status
    
    Args:
        df: a slice of the eBird dataset in a dataframe
        confirmation_status:
            if 'approved': keep APPROVED = 1
            if 'unflagged': keep APPROVED = 1, REVIEWED = 0
            if 'flagged_approved': keep APPROVED = 1, REVIEWED = 1
            if 'unconfirmed': keep APPROVED = 0, REVIEWED = 1
            if anything else: *does not filter*
    """
    # Removed unconfirmed observations or reviewed observations, if desired
    if status == "unconfirmed":
        df = df[df["APPROVED"] == 0]
    elif status in ["approved", "unflagged", "flagged-approved"]:
        df = df[df["APPROVED"] == 1]
        if status == "unflagged":
            df = df[df["REVIEWED"] == 0]
        elif status == "flagged-approved":
            df = df[df["REVIEWED"] == 1]
        
    return df

def create_grid_cells(df, resolutions=[2,3,4]):
    """Convert latitudes and longitudes to H3 cells
    
    Adds H3 cells in every desired resolution to the source dataframe
    
    Args:
        df: a dataframe with columns LATITUDE and LONGITUDE
        resolutions: the H3 resolutions to use
    """
    def _latlongchecker(row, resolution):
        if type(row.LATITUDE) != float or type(row.LONGITUDE) != float:
            print("WHAT!!!")
            print(row.LATITUDE, type(row.LATITUDE))
            print(row.LONGITUDE, type(row.LONGITUDE))
        return h3.latlng_to_cell(row.LATITUDE, row.LONGITUDE, resolution)
    
    # Convert latitude and longitude to an H3 hexagon ID
    for resolution in resolutions:
        df[f'hex_id_{resolution}'] = df.apply(lambda row:  _latlongchecker(row, resolution), axis=1)

#     # This one is slightly slower
#     def _latlong_to_cells(row, resolutions=resolutions):
#         return [h3.latlng_to_cell(row.LATITUDE, row.LONGITUDE, resolution) for resolution in resolutions]
    
#     row_names = [f'hex_id_{resolution}' for resolution in resolutions]
#     df[row_names] = df.apply(_latlong_to_cells, axis='columns', result_type='expand')

    return df


def get_grid_cell_species_data(cell_df, sp, subspp, resolution):
    """Get # of checklists containing a species and each subspecies

    Args:
    - cell_df: pd.DataFrame, dataframe of all observations for a single grid cell (1 row per observation)
    - sp: str, scientific name of species
    - subspp: list of str, scientific names of subspecies for this species

    Returns:
    - cell_data: dict, with keys 'cell_id', species name, and subspecies names
    """
    # Total number of checklists containing the species
    num_checklists = cell_df["SAMPLING EVENT IDENTIFIER"].nunique()

    # Create a dict of # checklists containing sp for all cells
    try:
        cell_data = {'cell_id': cell_df[f"hex_id_{resolution}"].iloc[0]}
    except:
        print(cell_df)
    cell_data[sp] = num_checklists

    # Add number of checklists containing each subspecies
    for subsp in subspp:
        num_subsp = cell_df[cell_df["SUBSPECIES SCIENTIFIC NAME"] == subsp].shape[0]
        cell_data[subsp] = num_subsp

    return cell_data

def get_subspecies_df(sp, sp_df, subspp, resolution):
    """Make dataframe of species & subspecies data for every cell for a given species

    Args:
    - sp: str, scientific name of species
    - df: pd.DataFrame, dataframe of data for this species
    - subspp: list of str, scientific names of subspecies for this species
    - resolution: int, H3 resolution level
    """

    # Create a dict of # checklists containing sp for all cells
    cell_dicts = []
    for cell in sp_df[f"hex_id_{resolution}"].unique():
        cell_df = sp_df[sp_df[f"hex_id_{resolution}"] == cell]
        cell_data = get_grid_cell_species_data(cell_df, sp, subspp, resolution)
        cell_dicts.append(cell_data)

    sp_cell_df = pd.DataFrame(cell_dicts, index=range(len(cell_dicts)))
    sp_cell_df.set_index("cell_id", inplace=True)

    return sp_cell_df


def filter_species(df, keep_species):
    """Filter dataframe to only include species in the list
    """
    filtered = df[df["SCIENTIFIC NAME"].isin(keep_species)]
    kept_species = list(filtered["SCIENTIFIC NAME"].unique())
    return filtered, kept_species


def cast_types(df):
    """Get correct types for columns and remove any uncastable entires
    """
    df['LATITUDE'] = pd.to_numeric(df['LATITUDE'], errors='coerce') 
    df['LONGITUDE'] = pd.to_numeric(df['LONGITUDE'], errors='coerce')
    return df.dropna(subset=['LATITUDE', 'LONGITUDE'])     # Drop rows without float latitudes


# The dictionary we've created of all species and their infraspecies, by category
spp_dict = json.load(open("infraspecies_ebird.json"))
spp_with_infras = [sp for sp, info in spp_dict.items() if len(info["infraspecies"].keys()) > 0]

# Only include the columns we're using
use_cols = [
        'SCIENTIFIC NAME', 'SUBSPECIES SCIENTIFIC NAME',
        'SAMPLING EVENT IDENTIFIER', 'GROUP IDENTIFIER',
        'LATITUDE', 'LONGITUDE', 
        'REVIEWED', 'APPROVED', 'OBSERVATION DATE']

# Process the whole eBird dataset
dataset_filepath = f"data/ebd_relOct-2024.txt"


# Where we will store each batch of data
batch_directory = Path('batches/')
batch_directory.mkdir(exist_ok=True)

statuses = ["unflagged", "flagged-approved"] 

# Read in CSV in batches
chunk_rows = 10000000

s 
# Track progress separately for every task in the job array
#job_num = os.environ.get('SLURM_ARRAY_TASK_ID')
job_num = 2

# Keep track of the progress made in each batch using a tracker CSV
Path("progress_trackers").mkdir(exist_ok=True)
tracker_filepath = f"progress_trackers/ebd_tracker_rowsperchunk-{chunk_rows}_job{job_num}.csv"

import os

# If already started processing, pick up where we left off 
if Path(tracker_filepath).exists():

    # Read the tracker in regular pandas (pdr)
    tracker = pdr.read_csv(tracker_filepath)
    tracker["spp_to_do"] = tracker["spp_to_do"].apply(ast.literal_eval) # Track which species are in this chunk
    tracker["spp_done"] = tracker["spp_done"].apply(ast.literal_eval) # Track what species are complete from this chunk
    start_idx = tracker.index[-1]
    spp_to_do = set(tracker.loc[start_idx].spp_to_do) - set(tracker.loc[start_idx].spp_done)
    if spp_to_do == set():
        prev_end_row = tracker.loc[start_idx].end_row
        prev_start_row = tracker.loc[start_idx].start_row
        if prev_end_row - prev_start_row < chunk_rows:
            print("No more data to process, total rows in dataset: ", prev_end_row)
            assert(False)
        skiprows = tracker.loc[start_idx].end_row # This is the row after the last one we processed
        start_idx = start_idx + 1
        spp_to_do = None
    else:
        skiprows = tracker.loc[start_idx].start_row

else:
    tracker = pdr.DataFrame(columns=["start_row", "end_row", "spp_to_do", "spp_done"])
    start_idx = job_num 
    spp_to_do = None
    skiprows = job_num * chunk_rows

for idx, chunk in enumerate(pd.read_csv(
    dataset_filepath, chunksize=chunk_rows, header=0, 
    skiprows=range(1,skiprows), usecols=use_cols
    sep="\t", 
    keep_default_na=False  # Prevent treating empty strings as NaN
)):
    print(f" ** Chunk memory usage - {sum(chunk.memory_usage()) * 0.000001} MB for {len(chunk.index)} Rows")
    
    print(f"Processing chunk {idx}...")
    print("Start", (start_idx + idx)*chunk_rows, "End", (start_idx + idx)*chunk_rows+chunk_rows)

    # Check whether we are finishing or have finished all chunks 
    if chunk.shape[0] == 0:
        print("No more data to process, total rows in dataset: ", (start_idx + idx)*chunk_rows)
        break
    if chunk.shape[0] < chunk_rows:
        end_row = (start_idx+idx)*chunk_rows + chunk.shape[0]+1
        print(f"Last chunk, total rows in dataset:", end_row)
    else:
        end_row = (start_idx + idx)*chunk_rows+chunk_rows

    # Clean up the dataframe and subset to needed entries
    cleaned = cast_types(chunk)             # Prepare datatypes in the dataset
    cleaned = remove_duplicates(cleaned)    # Remove duplicate checklists
    cleaned, species_in_chunk = filter_species(
        cleaned, keep_species=spp_with_infras) # Remove spp with no reportable infraspecies

    # Get H3 cells for all observations
    cleaned = create_grid_cells(cleaned)       

    # Determine which species there are to evaluate in the chunk
    if spp_to_do == None: # Add new row
        spp_to_do = species_in_chunk
        tracker.loc[start_idx+idx] = [(start_idx + idx)*chunk_rows, end_row, spp_to_do, []]

    # Do each species separately to easily pick back up where left off
    for sp in ProgIter(spp_to_do):
        for status in statuses:
            # Filter to set of species and observation statuses
            filtered = filter_by_status(cleaned, status)
            filtered, _ = filter_species(filtered, keep_species=[sp]) # Subset to the needed spp
            if filtered.shape[0] == 0: continue

            # Get list of countable subspecies from each ssp group
            subspp = []
            for ssp_type, ssp in spp_dict[sp]['infraspecies'].items(): subspp.extend(ssp.keys())

            # Save data on # obs of each subspp for each cell for each resolution
            for resolution in resolutions:
                filename = batch_directory.joinpath(f'{sp}_row{(start_idx+idx)*chunk_rows}-{end_row}_status-{status}_resolution{resolution}.csv')
                batch_df = get_subspecies_df(sp, filtered, subspp, resolution)
                batch_df.to_csv(filename)

            # Update the tracker
            tracker.loc[start_idx+idx].spp_done += [sp]
            tracker.to_csv(tracker_filepath, index=False)

    spp_to_do = None
    break
# Out:
#  ** Chunk memory usage - 720.000128 MB for 10000000 Rows
# Processing chunk 0...
# Start 20000000 End 30000000
#  100.00% 1352/1352... rate=13.77 Hz, eta=0:00:00, total=0:04:09
# CPU times: user 4min 45s, sys: 8.17 s, total: 4min 53s
# Wall time: 5min 33s

# %% [markdown]
# ## Sum up the batches

# %%
sp_cell_df_directory = Path('sp_cell_dfs/')
sp_cell_df_directory.mkdir(exist_ok=True)

def parse_batch_files(batch_directory):
    batch_files = list(batch_directory.glob("*.csv"))
    file_info = [n.name.split("_") for n in batch_files]
    files = pd.DataFrame(file_info, columns=['SCIENTIFIC NAME', 'ROW RANGE', 'RESOLUTION'])
    files['FILENAME'] = batch_files
    for (species, resolution), species_df in files.groupby(["SCIENTIFIC NAME", 'RESOLUTION']):
        species = species.replace(" ", "-")
        resolution = resolution[:-4]
        all_dataframes = [pd.read_csv(f, index_col=0) for f in species_df.FILENAME] 
        sp_cell_df = reduce(lambda a, b: a.add(b, fill_value=0), all_dataframes)
        filename = sp_cell_df_directory.joinpath(f'{species}_{resolution}.csv')
        sp_cell_df.to_csv(filename)



parse_batch_files(batch_directory)

# %%
from pathlib import Path
l = list(Path("batches").glob("*.csv"))

# %% [markdown]
# # Create maps

# %%
import re

# %%
from shapely.geometry import Polygon, LineString, mapping
from shapely.ops import split
import json
import geopandas as gpd
import numpy as np
import networkx as nx
import colorsys
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from colormath.color_objects import sRGBColor, LabColor
from colormath.color_conversions import convert_color
from colormath import color_diff_matrix
#from colormath.color_diff import delta_e_cie2000 # deprecated and doesn't work anymore, reimplemented below

def get_infraspecies_relationships(sp, spp_dict=spp_dict):
    data = spp_dict[sp]['infraspecies']
    
    # Get a list of each type of infraspecies
    if "issf" in data.keys():
        issfs = [k.replace(sp+' ', '') for k in data["issf"].keys()] # Recognized ssp or ssp groups
    else:
        issfs = []
    if "form" in data.keys():
        forms = [k.replace(sp+' ', '') for k in data["form"].keys()] # Forms
    else:
        forms = []
    if "intergrade" in data.keys():
        intergrades = [k.replace(sp+' ', '') for k in data["intergrade"].keys()] # Intergrades (between ssp? forms?)
    else:
        intergrades = []

    intergrade_to_parents = dict()
    forms_to_parents = dict()
    top_level_intergrades = []
    top_level_forms = []

    # Find parents of the intergrades, if any are in the eBird taxonomy
    # Also determine which intergrades, if any, have no parents
    for intergrade in intergrades:
        parents = [i.strip() for i in intergrade.split('x')]
        # Check if all are true
        if all([p in issfs+forms for p in parents]):
            intergrade_to_parents[intergrade] = parents
        else:
            top_level_intergrades.append(intergrade)

    # Find parents of the forms, if any are in the eBird taxonomy
    # Also determine which forms, if any, have no parents
    for form in forms:
        # Split the form into its individual components
        form_parts = set(form.split("/"))
        
        parent_issfs = []
        for component in issfs:
            # Split the list component into subparts and check if all are in the form_parts
            component_parts = set(component.split("/"))
            if component_parts <= form_parts:  # Check if component_parts is a subset of form_parts
                parent_issfs.append(component)
        if len(parent_issfs):
            forms_to_parents[form] = parent_issfs
        else:
            top_level_forms.append(form)
        
    return issfs, forms, intergrades, intergrade_to_parents, forms_to_parents, top_level_intergrades, top_level_forms


def rgb_to_hex(rgb):
    """Convert an (R, G, B) tuple to a hex color (#RRGGBB)."""
    return "#{:02x}{:02x}{:02x}".format(*rgb)


def hex_to_rgb(hex_color):
    """Convert hex color (#RRGGBB) to an (R, G, B) tuple."""
    hex_color = hex_color.lstrip('#')
    return tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))

def combine_rgb_colors(rgb_colors, fracs):
    """Combine a list of RGB colors proportionally."""
    if sum(fracs) == 0:
        return "#999999"
    else:
        combined_rgb = tuple(
            int(sum(frac * color[channel] for color, frac in zip(rgb_colors, fracs)))
            for channel in range(3)
        )
    return rgb_to_hex(combined_rgb)

def name_to_base_hue(name):
    """Generate a base hue from a name."""
    base_hue = hash(name) % 360
    return base_hue

def average_hues(hues):
    """Average a list of hues on the circular scale."""
    x = np.mean([np.cos(np.radians(h)) for h in hues])
    y = np.mean([np.sin(np.radians(h)) for h in hues])
    avg_hue = np.degrees(np.arctan2(y, x)) % 360
    return avg_hue


def delta_e_cie2000(color1, color2, Kl=1, Kc=1, Kh=1):
    """
    Calculates the Delta E (CIE2000) of two colors.
    """
    def _get_lab_color1_vector(color):
        return np.array([color.lab_l, color.lab_a, color.lab_b])
    def _get_lab_color2_matrix(color):
        return np.array([(color.lab_l, color.lab_a, color.lab_b)])

    color1_vector = _get_lab_color1_vector(color1)
    color2_matrix = _get_lab_color2_matrix(color2)
    delta_e = color_diff_matrix.delta_e_cie2000(
        color1_vector, color2_matrix, Kl=Kl, Kc=Kc, Kh=Kh)[0]
    return delta_e

def rgb_to_lab(rgb):
    """Convert an RGB color (0-255) to LAB color space."""
    srgb = sRGBColor(rgb[0] / 255, rgb[1] / 255, rgb[2] / 255, is_upscaled=False)
    return convert_color(srgb, LabColor)

def hsl_to_rgb(hue, saturation, lightness):
    """Convert HSL values to RGB (0-255)."""
    r, g, b = colorsys.hls_to_rgb(hue / 360, lightness, saturation)
    return (int(r * 255), int(g * 255), int(b * 255))


def is_color_too_similar(hue1, hue2, threshold=15):
    """
    Check if two hues are too similar, accounting for perceptual non-uniformity.
    Compare using the CIEDE2000 formula in the LAB color space.

    Higher threshold ==> colors need to be more different
    """

    # Convert hues to RGB colors using fixed saturation and lightness for comparison
    rgb1 = hsl_to_rgb(hue1, 0.8, 0.5)  # Vivid, medium lightness
    rgb2 = hsl_to_rgb(hue2, 0.8, 0.5)

    # Convert RGB to LAB for perceptual uniformity
    lab1 = rgb_to_lab(rgb1)
    lab2 = rgb_to_lab(rgb2)

    # Calculate perceptual difference using CIEDE2000
    delta_e = delta_e_cie2000(lab1, lab2)
    return delta_e < threshold


def create_distribution_adjacency_matrix(data, subspecies_cols, cell_col='cell_id'):
    """
    Create an adjacency matrix based on subspecies distribution similarities.

    Parameters:
    - data: DataFrame with cells as rows and subspecies counts as columns.
    - subspecies_cols: List of column names corresponding to subspecies counts.
    - cell_col: Column name for cell identifiers (optional, for reference).

    Returns:
    - adjacency_matrix: A NumPy array where element [i, j] is the similarity between subspecies distributions.
    - subspecies_list: The order of subspecies corresponding to matrix rows/columns.
    """
    # Subset the subspecies columns
    subspecies_data = data[subspecies_cols]

    # Normalize each cell's counts to proportions
    subspecies_distribution = subspecies_data.div(subspecies_data.sum(axis=1), axis=0).fillna(0)

    # Compute cosine similarity between each pair of subspecies
    adjacency_matrix = cosine_similarity(subspecies_distribution.T)

    # Return the matrix and list of subspecies
    return adjacency_matrix, subspecies_cols


def hue_to_hex_vibrant(hue):
    saturation, lightness = 0.8, 0.5  # Vivid, medium colors
    r, g, b = colorsys.hls_to_rgb(hue / 360, lightness, saturation)
    return rgb_to_hex((int(r * 255), int(g * 255), int(b * 255)))


def style_function(feature, subspp_colors):
    """Style a cell based on the proportion of subspecies."""
    properties = feature['properties']
    subspecies_values = dict()
    for subsp in subspp_colors.keys():
        val = properties.get(subsp, 0)
        if val > 0:
            subspecies_values[subsp] = val
    
    # Normalize the values to sum up to 1 for proportional allocation
    total = sum(subspecies_values.values())
    if total > 0:
        fracs = [value / total for value in subspecies_values.values()]
    else:
        fracs = [0 for _ in subspecies_values]
    
    # Get RGB colors for each subspecies
    hex_colors = [subspp_colors[subsp] for subsp in subspecies_values]
    rgb_colors = [hex_to_rgb(color) for color in hex_colors]
    
    # Combine colors based on the proportional fractions
    cell_color = combine_rgb_colors(rgb_colors, fracs)
    
    return {
        'fillColor': cell_color,  # Cell color
        'color': cell_color,  # Border color
        'weight': 1,  # Border weight
        'fillOpacity': 0.6,  # Cell fill transparency
    }

def calculate_overlap_intensity(overlap_matrix):
    """
    Calculate the overlap intensity for each subspecies.
    Overlap intensity is defined as the proportion of cells that overlap with others.

    Parameters:
    - overlap_matrix: A square matrix where overlap_matrix[i][j] represents the overlap between subspecies[i] and subspecies[j].

    Returns:
    - A list of overlap intensities for each subspecies.
    """
    total_overlap = np.sum(overlap_matrix, axis=1)  # Total overlap for each subspecies
    max_overlap = np.sum(overlap_matrix, axis=1) - np.diagonal(overlap_matrix)  # Exclude self-overlap
    return total_overlap / max_overlap


def generate_priority_hues(subspecies, overlap_matrix):
    """
    Assign perceptually distinct hues to subspecies, prioritizing those with higher overlap intensity.

    Parameters:
    - subspecies: List of subspecies names.
    - overlap_matrix: A square matrix where overlap_matrix[i][j] represents the overlap between subspecies[i] and subspecies[j].

    Returns:
    - A dictionary mapping each subspecies to a distinct hue (in degrees, 0-360).
    """
    n_subspecies = len(subspecies)

    # Step 1: Generate perceptually distinct hues (0-360 degrees)
    hues = np.linspace(0, 360, n_subspecies, endpoint=False)

    # Step 2: Calculate overlap intensity
    overlap_intensity = calculate_overlap_intensity(overlap_matrix)

    # Step 3: Assign hues based on overlap intensity and relationships
    G = nx.Graph()
    for i, sp1 in enumerate(subspecies):
        for j, sp2 in enumerate(subspecies):
            if overlap_matrix[i][j] > 0.1:  # Add edge if overlap is above threshold
                G.add_edge(sp1, sp2, weight=overlap_matrix[i][j])

    # Sort subspecies by overlap intensity
    subspecies_sorted = sorted(zip(subspecies, overlap_intensity), key=lambda x: x[1], reverse=True)

    # Assign hues sequentially to prioritize highly overlapping subspecies
    assigned_hues = {}
    used_hues = set()
    for subsp, _ in subspecies_sorted:
        # Find the most distinct unused hue
        best_hue = None
        max_dist = -1
        for i, hue in enumerate(hues):
            if i in used_hues:
                continue
            # Check perceptual distance to already assigned hues
            if assigned_hues:
                dist = np.min(
                    [min(abs(hue - assigned_hues[sp]), 360 - abs(hue - assigned_hues[sp])) for sp in assigned_hues]
                )
            else:
                dist = float("inf")
            
            if dist > max_dist:
                max_dist = dist
                best_hue = i

        # Assign the best hue
        assigned_hues[subsp] = hues[best_hue]
        used_hues.add(best_hue)
    
    return assigned_hues


def get_bounds(geojson_result):
    """
    Calculate the bounding box of all features in the GeoJSON.

    Args:
    - geojson_result: GeoJSON string with features.

    Returns:
    - Bounds as [[southwest_lat, southwest_lon], [northeast_lat, northeast_lon]].
    """
    import json
    #geojson_data = json.loads(geojson_result)
    geojson_data = geojson_result
    all_coords = []

    for feature in geojson_data['features']:
        # Extract all coordinates from the polygon or multipolygon
        coords = feature['geometry']['coordinates']
        if feature['geometry']['type'] == "Polygon":
            all_coords.extend(coords[0])  # Add outer ring of the polygon
        elif feature['geometry']['type'] == "MultiPolygon":
            for poly in coords:
                all_coords.extend(poly[0])  # Add outer ring of each polygon

    # Extract longitudes (x) and latitudes (y) correctly
    lons, lats = zip(*all_coords)
    return [[min(lats), min(lons)], [max(lats), max(lons)]]


def split_polygon_at_line(polygon, line):
    """
    Splits a GeoJSON polygon at a given GeoJSON line.
    
    Parameters:
        polygon (dict): shapely representation of the polygon.
        line (dict): shapely representation of the line.
    
    Returns:
        list: A list of GeoJSON polygons after splitting.
    """
    
    # Perform the split
    split_result = split(polygon, line)
    
    # Convert Shapely polygons back to GeoJSON
    split_geojsons = [mapping(geom) for geom in split_result.geoms]
    
    return split_geojsons


def split_at_dateline(geojson):
    """
    Splits polygons that cross the International Date Line (180° longitude).
    
    Parameters:
    - geojson: A GeoJSON-like dictionary of geometries.
    
    Returns:
    - A new GeoJSON with adjusted geometries.
    """
    dateline = LineString([(180, 90), (180, -90)])
    adjusted_polygons = []
    
    for feature in geojson['features']:
        geom = feature['geometry']
        polygon = Polygon(geom['coordinates'][0])

        # Check if the polygon crosses the dateline
        if not polygon.is_valid:
            polygon = polygon.buffer(0)  # Fix invalid geometries

        # Check if any of the polygon's coordinates are within 5 degrees of the dateline
        if any(abs(lon) > 170 for lon, _ in polygon.exterior.coords) and any(abs(lon1 - lon2) > 180 for lon1, lon2 in zip(polygon.exterior.xy[0][:-1], polygon.exterior.xy[0][1:])):
            # For all the longitudes that are less than -170, add 360 to them
            new_coords = [
                [(x + 360 if x < -170 else x, y) for x, y in polygon.exterior.coords]
            ]
            adjusted_polygons.append({
                "type": "Feature",
                "geometry": {
                    "type": "Polygon",
                    "coordinates": new_coords
                },
                "properties": feature['properties']
            })
        else:
            adjusted_polygons.append(feature)
    
    return {
        "type": "FeatureCollection",
        "features": adjusted_polygons
    }


def get_range_size(sp_cell_df, ssp):
    """Calculate the range size of a subspecies."""
    return (sp_cell_df[ssp] > 0).astype(int).sum()

def get_color_mapping(sp_cell_df):
    # Get the relationships between the infraspecies (ISSFs, forms, intergrades)
    issfs, forms, intergrades, inter_to_p, form_to_p, top_inter, top_form = get_infraspecies_relationships(species, spp_dict)

    # Get colors for the top-level infraspecies based on their geographic overlap
    top_level_infras = [*issfs, *top_inter, *top_form]
    sp_cell_df.columns = sp_cell_df.columns.str.replace(species + ' ', "")
    overlap_matrix, top_level_infras = create_distribution_adjacency_matrix(sp_cell_df, top_level_infras)
    ssp_hues = generate_priority_hues(top_level_infras, overlap_matrix)

    # Get colors for the lower-level infraspecies by averaging their "parent" infraspecies
    for intergrade, parents in inter_to_p.items():
        ssp_hues[intergrade] = average_hues([ssp_hues[parent] for parent in parents])
    for form, parents in form_to_p.items():
        ssp_hues[form] = average_hues([ssp_hues[parent] for parent in parents])

    # Convert hues to vibrant colors
    ssp_colors = {ssp: hue_to_hex_vibrant(hue) for ssp, hue in ssp_hues.items()}

    # Organize subspecies into categories and calculate their range sizes (from largest to smallest)
    sorted_issfs = sorted(issfs, key=lambda ssp: get_range_size(sp_cell_df, ssp), reverse=True)
    sorted_forms = sorted(forms, key=lambda ssp: get_range_size(sp_cell_df, ssp), reverse=True)
    sorted_intergrades = sorted(intergrades, key=lambda ssp: get_range_size(sp_cell_df, ssp), reverse=True)

    return ssp_colors, sorted_issfs, sorted_forms, sorted_intergrades

def get_ssp_common_name(species, subsp, taxonomy=taxonomy):
    # Look up the PRIMARY_COM_NAME for the subspecies
    subsp_name = taxonomy[taxonomy['SCI_NAME'] == f"{species} {subsp}"].PRIMARY_COM_NAME.values[0]
    # Get the part in the parentheses
    subsp_name = subsp_name.split('(')[-1].split(')')[0] if '(' in subsp_name else subsp
    return subsp_name


def reduce_precision(geojson_data, precision):
    def round_coords(coords):
        return [[round(coord[0], precision), round(coord[1], precision)] for coord in coords]
    
    def process_feature(feature):
        if feature['geometry']['type'] == 'Polygon':
            feature['geometry']['coordinates'] = [round_coords(coords) for coords in feature['geometry']['coordinates']]
        elif feature['geometry']['type'] == 'MultiPolygon':
            feature['geometry']['coordinates'] = [
                [round_coords(coords) for coords in polygon]
                for polygon in feature['geometry']['coordinates']
            ]
        return feature

    geojson_data['features'] = [process_feature(feature) for feature in geojson_data['features']]
    return geojson_data

def choropleth_map(sp_cell_df, common_name, subspp_colors, sorted_issfs, sorted_forms, sorted_intergrades, taxonomy=taxonomy):
    """Creates a choropleth map given species data."""
    
    f = folium.Figure()
    map = folium.Map(location=[47, -122], zoom_start=5, tiles="cartodbpositron", control_scale=True)
    f.add_child(map)

    sp = sp_cell_df.columns[0]
    subspp = sp_cell_df.columns[1:]
    
    # Create polygon features with 
    list_features = []
    for _, row in sp_cell_df.iterrows():
        # Calculate the relative percentage of sightings of each subspecies for each cell
        percentages = (row[subspp] / sum(row[subspp])) * 100
        percentages = round(percentages, 0)
        percentages_dict = percentages.to_dict()
        
        # Calculate total reports across all subspecies for each cell
        total_reports = row[subspp].sum()

        # Precompute tooltip text showing only subspecies with nonzero percentages
        percentages_dict_ordered = pd.DataFrame(percentages_dict, index=['pct']).T.query('pct > 0')['pct'].sort_values(ascending=False).to_dict()
        
        # Start tooltip container
        tt1_style = '''.tt1 {min-width: 100px; max-width: 300px; overflow: auto;}'''
        tooltip_text = '<div class="tt1">'

        # Add header and create a flex container for total reports and percentages

        tt2_style = '''.tt2 {display: flex; justify-content: space-between; margin-top: 5px;}'''
        tt3_style = '''.tt3 {margin-right: 10px;}'''
        tt4_style = '''.tt4 {text-align: right; background: ;}'''
        total_reports = row[subspp].sum()
        tooltip_text += f'''<div class="tt2"><div class="tt3"><strong>Reported taxa</strong><br>Total reports: {total_reports:.0f}</div><div class="tt4">'''
        # Add percentages to the right-aligned div
        if total_reports > 0:
            for subsp, percent in percentages_dict_ordered.items():
                if percent > 0:
                    subsp_common_name = get_ssp_common_name(sp, subsp)
                    tooltip_text += f"<div>{subsp_common_name}: {percent:.0f}%</div>" if percent > 0.5 else ""
        else:
            tooltip_text += '''</div>None</div>'''

        # Close all divs
        tooltip_text += '''</div></div></div>'''

        # Add the tooltip to the feature's properties
        percentages_dict_ordered["tooltip"] = tooltip_text

        # Convert the H3 cell into a geometry
        geometry_for_row = h3.cells_to_geo(cells=[row.name])

        # Add a GeoJSON Feature to the list of features
        feature = Feature(
            geometry=geometry_for_row,
            id=row.name,
            properties=percentages_dict_ordered
        )
        list_features.append(feature)

    # Create a GeoJSON FeatureCollection with the list of features
    feat_collection = FeatureCollection(list_features)
    geojson_result = json.dumps(feat_collection)

    # Deal with geometries that cross the International Date Line
    geojson_result = split_at_dateline(json.loads(geojson_result))

    # Reduce precision to 3 digits (111 meters)
    geojson_result = reduce_precision(geojson_result, precision=3)
    
    # Add GeoJSON layer to the map
    folium.GeoJson(
        geojson_result,
        style_function=lambda feature: style_function(feature, subspp_colors),
        name=f'{sp} Subspecies Map'
    ).add_to(map)
    
    # Add a tooltip to the GeoJSON layer
    folium.GeoJson(
        geojson_result,
        style_function=lambda feature: {
            'weight': 0, 
            'color': 'transparent',  
            'fillOpacity': 0.6 
        },
        tooltip=GeoJsonTooltip(
            fields=["tooltip"],
            aliases=[None],  # No additional label prepended
            localize=True,
            sticky=True,
            labels=False,  # Disable default labels
            html=True  # Enable HTML formatting in the tooltip
        )
    ).add_to(map)


    # Add legend with subheaders
    legend_html = f"""
    <div style="position: fixed; top: 10px; right: 10px; max-width: 200px; height: auto; z-index: 9999; background-color: white; box-shadow: 0 0 5px rgba(0, 0, 0, 0.2); border: 1px solid lightgray; border-radius: 5px; padding: 10px; font-size: 10px;">
        <div style="font-size: 12px;"><strong>{common_name}</strong></div>
    """
    
    # Add subheaders and sorted species
    issf_colors = {k: subspp_colors[k] for k in sorted_issfs}
    form_colors = {k: subspp_colors[k] for k in sorted_forms}
    intergrade_colors = {k: subspp_colors[k] for k in sorted_intergrades}
    categories = [("Subspecies", issf_colors), ("Forms", form_colors), ("Intergrades", intergrade_colors)]
    # Remove any categories where the dictionary has no keys
    categories = [(category, ssp_in_category) for category, ssp_in_category in categories if ssp_in_category]

    # Create species and colors part of legend
    for category, sorted_subspecies in categories:
        legend_html += f'<div style="margin-top:10px;"><b>{category}</b></div>'
        for subsp in sorted_subspecies:
            subsp_common_name = get_ssp_common_name(sp, subsp)
            if subsp_common_name == subsp.strip('[]'): # Only display one name if no unique common name
                display_name = subsp
            else:
                display_name = f"{subsp_common_name} ({subsp})"

            display_name = '/<wbr>'.join(display_name.split('/')) # Add available wordbreaks for long slash names
            color = subspp_colors.get(subsp, "#ccc")  # Default color if no color is found

            # Get link to the subspecies's eBird species account
            subsp_code = taxonomy[taxonomy['SCI_NAME'] == f"{sp} {subsp}"].SPECIES_CODE.values[0]
            subsp_link = f"https://ebird.org/species/{subsp_code}"
            

            subsp_display = f"""
            <div style="display: inline-block; max-width: 150px; white-space: normal; overflow-wrap: break-word;">
                <a href="{subsp_link}" target="_blank">{display_name}</a>
            </div>
            """
            # Format subspecies name next to colors
            legend_html += f"""
            <div style="margin-top: 5px;">
                <span style="display: inline-block; width: 20px; height: 10px; margin-right: 5px; background-color: {color};"></span>
                {subsp_display}
            </div>
            """
    legend_html += "</div>"
    
    legend_element = folium.Element(legend_html)
    map.get_root().html.add_child(legend_element)
    map.get_root().html.add_child(folium.Element(f"""
        <style>
            {tt1_style}
            {tt2_style}
            {tt3_style}
            {tt4_style}
        </style>"""))

    # Calculate bounds and adjust the map's view
    bounds = get_bounds(geojson_result)
    map.fit_bounds(bounds)

    # TODO: String manipulations to make HTML smaller?
    string_so_far = map.get_root().render()
    return string_so_far


remake_maps = True
include_flagged_confirmed = True
spp_with_infras = [sp for sp, info in spp_dict.items() if len(info["infraspecies"].keys()) > 0]
for sp_code in ['Acanthis sp_codes:
    subspp_colors = None
    print("\nMapping", sp_code)
    common_name = taxonomy[taxonomy['SPECIES_CODE'] == sp_code].PRIMARY_COM_NAME.values[0]
    for resolution in resolutions: #[2,3,4]
        species = taxonomy[taxonomy['PRIMARY_COM_NAME'] == common_name].SCI_NAME.values[0]
        map_filename = f"docs/maps/{species.replace(' ', '-')}_{resolution}.html"
        if Path(map_filename).exists() and not remake_maps:
            print("Map already exists for", species, "at resolution", resolution)
            continue
        if include_flagged_confirmed:
            dataname1 = f"sp_cell_dfs/{species.replace(' ', '-')}_status-unflagged_resolution{resolution}.csv"
            dataname2 = f"sp_cell_dfs/{species.replace(' ', '-')}_status-flagged-approved_resolution{resolution}.csv"
        else:
            dataname = f"sp_cell_dfs/{species.replace(' ', '-')}_status-unflagged_resolution{resolution}.csv"
        if not Path(dataname).exists():
            print("No data for", species, "at resolution", resolution)
            continue
        sp_cell_df = pd.read_csv(dataname, index_col=0)
        sp_cell_df.columns = sp_cell_df.columns.str.replace(species + ' ', "")
        subspecies = sp_cell_df.columns[1:]
        if resolution == 2 or subspp_colors == None:
            subspp_colors, sorted_issfs, sorted_forms, sorted_intergrades = get_color_mapping(sp_cell_df)
            
        m = choropleth_map(sp_cell_df, common_name, subspp_colors, sorted_issfs, sorted_forms, sorted_intergrades)
        map_filename = f"docs/maps/{species.replace(' ', '-')}_{resolution}.html"
        #m.save(map_filename)
        with open(map_filename, 'w') as f:
            f.write(m)

# %%
taxonomy['SCIENTIFIC NAME'] in
# Out:
# 0        ostric2
# 1        ostric3
# 2         y00934
# 3        soucas1
# 4        dwacas1
#           ...
# 17410    bltgro2
# 17411    saltat1
# 17412    thraup3
# 17413    passer1
# 17414      bird1
# Name: SPECIES_CODE, Length: 17415, dtype: object

# %% [markdown]
# ## Create a CSV of map URLs for the website

# %%
df = pd.DataFrame(columns=["common_name", "scientific_name", "resolution", "map_url"])
maps_dir = Path("docs/maps")

# Sort maps taxonomically
maps_list = list(maps_dir.glob("*.html"))
species = {p.name.split('_')[0].replace('-', ' '): p for p in maps_list}
ordering = taxonomy[['SCI_NAME', 'TAXON_ORDER']].set_index("SCI_NAME").to_dict()['TAXON_ORDER']
maps_list = sorted(maps_list, key=lambda x: ordering[x.name.split('_')[0].replace('-', ' ')])

# Create table of common name, species, resolution, and map URL
# This is used by the website
for idx, file in enumerate(maps_list):
    resolution = file.stem.split("_")[-1]
    species = file.stem.replace(f"_{resolution}", "")
    common_name = taxonomy[taxonomy['SCI_NAME'] == species.replace('-', ' ')].PRIMARY_COM_NAME.values[0]
    #map_url = Path(Path(file).parent.stem).joinpath(Path(file).name)
    map_url = 'https://subspeciesmapper.netlify.app/' + str(file.relative_to(maps_dir))
    print(map_url)
    df.loc[idx] = [common_name, species, resolution, map_url]
df.to_csv("docs/data/map_data.csv", index=False)
# Out:
# https://subspeciesmapper.netlify.app/Apteryx-australis_3.html
# https://subspeciesmapper.netlify.app/Apteryx-australis_2.html
# https://subspeciesmapper.netlify.app/Apteryx-australis_4.html
# https://subspeciesmapper.netlify.app/Rhea-pennata_3.html
# https://subspeciesmapper.netlify.app/Rhea-pennata_2.html
# https://subspeciesmapper.netlify.app/Rhea-pennata_4.html
# https://subspeciesmapper.netlify.app/Nothocercus-bonapartei_4.html
# https://subspeciesmapper.netlify.app/Nothocercus-bonapartei_3.html
# https://subspeciesmapper.netlify.app/Nothocercus-bonapartei_2.html
# https://subspeciesmapper.netlify.app/Crypturellus-obsoletus_4.html
# https://subspeciesmapper.netlify.app/Crypturellus-obsoletus_2.html
# https://subspeciesmapper.netlify.app/Crypturellus-obsoletus_3.html
# https://subspeciesmapper.netlify.app/Crypturellus-noctivagus_2.html
# https://subspeciesmapper.netlify.app/Crypturellus-noctivagus_3.html
# https://subspeciesmapper.netlify.app/Crypturellus-noctivagus_4.html
# https://subspeciesmapper.netlify.app/Crypturellus-cinnamomeus_4.html
# https://subspeciesmapper.netlify.app/Crypturellus-cinnamomeus_2.html
# https://subspeciesmapper.netlify.app/Crypturellus-cinnamomeus_3.html
# https://subspeciesmapper.netlify.app/Dendrocygna-autumnalis_4.html
# https://subspeciesmapper.netlify.app/Dendrocygna-autumnalis_3.html
# https://subspeciesmapper.netlify.app/Dendrocygna-autumnalis_2.html
# https://subspeciesmapper.netlify.app/Anser-anser_2.html
# https://subspeciesmapper.netlify.app/Anser-anser_3.html
# https://subspeciesmapper.netlify.app/Anser-anser_4.html
# https://subspeciesmapper.netlify.app/Anser-albifrons_4.html
# https://subspeciesmapper.netlify.app/Anser-albifrons_2.html
# https://subspeciesmapper.netlify.app/Anser-albifrons_3.html
# https://subspeciesmapper.netlify.app/Branta-bernicla_4.html
# https://subspeciesmapper.netlify.app/Branta-bernicla_3.html
# https://subspeciesmapper.netlify.app/Branta-bernicla_2.html
# https://subspeciesmapper.netlify.app/Branta-hutchinsii_4.html
# https://subspeciesmapper.netlify.app/Branta-hutchinsii_3.html
# https://subspeciesmapper.netlify.app/Branta-hutchinsii_2.html
# https://subspeciesmapper.netlify.app/Branta-canadensis_4.html
# https://subspeciesmapper.netlify.app/Branta-canadensis_2.html
# https://subspeciesmapper.netlify.app/Branta-canadensis_3.html
# https://subspeciesmapper.netlify.app/Cygnus-columbianus_4.html
# https://subspeciesmapper.netlify.app/Cygnus-columbianus_2.html
# https://subspeciesmapper.netlify.app/Cygnus-columbianus_3.html
# https://subspeciesmapper.netlify.app/Chloephaga-picta_4.html
# https://subspeciesmapper.netlify.app/Chloephaga-picta_2.html
# https://subspeciesmapper.netlify.app/Chloephaga-picta_3.html
# https://subspeciesmapper.netlify.app/Plectropterus-gambensis_4.html
# https://subspeciesmapper.netlify.app/Plectropterus-gambensis_3.html
# https://subspeciesmapper.netlify.app/Plectropterus-gambensis_2.html
# https://subspeciesmapper.netlify.app/Tachyeres-pteneres_4.html
# https://subspeciesmapper.netlify.app/Tachyeres-pteneres_3.html
# https://subspeciesmapper.netlify.app/Tachyeres-pteneres_2.html
# https://subspeciesmapper.netlify.app/Tachyeres-brachypterus_4.html
# https://subspeciesmapper.netlify.app/Tachyeres-brachypterus_3.html
# https://subspeciesmapper.netlify.app/Tachyeres-brachypterus_2.html
# https://subspeciesmapper.netlify.app/Spatula-cyanoptera_3.html
# https://subspeciesmapper.netlify.app/Spatula-cyanoptera_2.html
# https://subspeciesmapper.netlify.app/Spatula-cyanoptera_4.html
# https://subspeciesmapper.netlify.app/Mareca-strepera_4.html
# https://subspeciesmapper.netlify.app/Mareca-strepera_2.html
# https://subspeciesmapper.netlify.app/Mareca-strepera_3.html
# https://subspeciesmapper.netlify.app/Anas-fulvigula_4.html
# https://subspeciesmapper.netlify.app/Anas-fulvigula_2.html
# https://subspeciesmapper.netlify.app/Anas-fulvigula_3.html
# https://subspeciesmapper.netlify.app/Anas-bahamensis_4.html
# https://subspeciesmapper.netlify.app/Anas-bahamensis_2.html
# https://subspeciesmapper.netlify.app/Anas-bahamensis_3.html
# https://subspeciesmapper.netlify.app/Anas-georgica_4.html
# https://subspeciesmapper.netlify.app/Anas-georgica_2.html
# https://subspeciesmapper.netlify.app/Anas-georgica_3.html
# https://subspeciesmapper.netlify.app/Anas-crecca_4.html
# https://subspeciesmapper.netlify.app/Anas-crecca_3.html
# https://subspeciesmapper.netlify.app/Anas-crecca_2.html
# https://subspeciesmapper.netlify.app/Anas-andium_4.html
# https://subspeciesmapper.netlify.app/Anas-andium_2.html
# https://subspeciesmapper.netlify.app/Anas-andium_3.html
# https://subspeciesmapper.netlify.app/Anas-flavirostris_3.html
# https://subspeciesmapper.netlify.app/Anas-flavirostris_2.html
# https://subspeciesmapper.netlify.app/Anas-flavirostris_4.html
# https://subspeciesmapper.netlify.app/Somateria-mollissima_2.html
# https://subspeciesmapper.netlify.app/Somateria-mollissima_3.html
# https://subspeciesmapper.netlify.app/Somateria-mollissima_4.html
# https://subspeciesmapper.netlify.app/Mergus-merganser_4.html
# https://subspeciesmapper.netlify.app/Mergus-merganser_2.html
# https://subspeciesmapper.netlify.app/Mergus-merganser_3.html
# https://subspeciesmapper.netlify.app/Oxyura-ferruginea_4.html
# https://subspeciesmapper.netlify.app/Oxyura-ferruginea_3.html
# https://subspeciesmapper.netlify.app/Oxyura-ferruginea_2.html
# https://subspeciesmapper.netlify.app/Alectura-lathami_2.html
# https://subspeciesmapper.netlify.app/Alectura-lathami_3.html
# https://subspeciesmapper.netlify.app/Alectura-lathami_4.html
# https://subspeciesmapper.netlify.app/Megapodius-freycinet_4.html
# https://subspeciesmapper.netlify.app/Megapodius-freycinet_3.html
# https://subspeciesmapper.netlify.app/Megapodius-freycinet_2.html
# https://subspeciesmapper.netlify.app/Ortalis-ruficauda_3.html
# https://subspeciesmapper.netlify.app/Ortalis-ruficauda_2.html
# https://subspeciesmapper.netlify.app/Ortalis-ruficauda_4.html
# https://subspeciesmapper.netlify.app/Ortalis-guttata_2.html
# https://subspeciesmapper.netlify.app/Ortalis-guttata_3.html
# https://subspeciesmapper.netlify.app/Ortalis-guttata_4.html
# https://subspeciesmapper.netlify.app/Penelope-superciliaris_4.html
# https://subspeciesmapper.netlify.app/Penelope-superciliaris_2.html
# https://subspeciesmapper.netlify.app/Penelope-superciliaris_3.html
# https://subspeciesmapper.netlify.app/Penelope-jacquacu_4.html
# https://subspeciesmapper.netlify.app/Penelope-jacquacu_2.html
# https://subspeciesmapper.netlify.app/Penelope-jacquacu_3.html
# https://subspeciesmapper.netlify.app/Pipile-cujubi_3.html
# https://subspeciesmapper.netlify.app/Pipile-cujubi_2.html
# https://subspeciesmapper.netlify.app/Pipile-cujubi_4.html
# https://subspeciesmapper.netlify.app/Crax-fasciolata_3.html
# https://subspeciesmapper.netlify.app/Crax-fasciolata_2.html
# https://subspeciesmapper.netlify.app/Crax-fasciolata_4.html
# https://subspeciesmapper.netlify.app/Numida-meleagris_4.html
# https://subspeciesmapper.netlify.app/Numida-meleagris_2.html
# https://subspeciesmapper.netlify.app/Numida-meleagris_3.html
# https://subspeciesmapper.netlify.app/Ptilopachus-petrosus_4.html
# https://subspeciesmapper.netlify.app/Ptilopachus-petrosus_3.html
# https://subspeciesmapper.netlify.app/Ptilopachus-petrosus_2.html
# https://subspeciesmapper.netlify.app/Colinus-virginianus_3.html
# https://subspeciesmapper.netlify.app/Colinus-virginianus_2.html
# https://subspeciesmapper.netlify.app/Colinus-virginianus_4.html
# https://subspeciesmapper.netlify.app/Cyrtonyx-montezumae_3.html
# https://subspeciesmapper.netlify.app/Cyrtonyx-montezumae_2.html
# https://subspeciesmapper.netlify.app/Cyrtonyx-montezumae_4.html
# https://subspeciesmapper.netlify.app/Xenoperdix-udzungwensis_2.html
# https://subspeciesmapper.netlify.app/Xenoperdix-udzungwensis_3.html
# https://subspeciesmapper.netlify.app/Xenoperdix-udzungwensis_4.html
# https://subspeciesmapper.netlify.app/Arborophila-cambodiana_4.html
# https://subspeciesmapper.netlify.app/Arborophila-cambodiana_3.html
# https://subspeciesmapper.netlify.app/Arborophila-cambodiana_2.html
# https://subspeciesmapper.netlify.app/Lophophorus-sclateri_4.html
# https://subspeciesmapper.netlify.app/Lophophorus-sclateri_3.html
# https://subspeciesmapper.netlify.app/Lophophorus-sclateri_2.html
# https://subspeciesmapper.netlify.app/Tympanuchus-cupido_3.html
# https://subspeciesmapper.netlify.app/Tympanuchus-cupido_2.html
# https://subspeciesmapper.netlify.app/Tympanuchus-cupido_4.html
# https://subspeciesmapper.netlify.app/Lagopus-lagopus_2.html
# https://subspeciesmapper.netlify.app/Lagopus-lagopus_3.html
# https://subspeciesmapper.netlify.app/Lagopus-lagopus_4.html
# https://subspeciesmapper.netlify.app/Canachites-canadensis_4.html
# https://subspeciesmapper.netlify.app/Canachites-canadensis_2.html
# https://subspeciesmapper.netlify.app/Canachites-canadensis_3.html
# https://subspeciesmapper.netlify.app/Lophura-inornata_2.html
# https://subspeciesmapper.netlify.app/Lophura-inornata_3.html
# https://subspeciesmapper.netlify.app/Lophura-inornata_4.html
# https://subspeciesmapper.netlify.app/Tropicoperdix-chloropus_2.html
# https://subspeciesmapper.netlify.app/Tropicoperdix-chloropus_3.html
# https://subspeciesmapper.netlify.app/Tropicoperdix-chloropus_4.html
# https://subspeciesmapper.netlify.app/Ortygornis-sephaena_4.html
# https://subspeciesmapper.netlify.app/Ortygornis-sephaena_2.html
# https://subspeciesmapper.netlify.app/Ortygornis-sephaena_3.html
# https://subspeciesmapper.netlify.app/Francolinus-francolinus_4.html
# https://subspeciesmapper.netlify.app/Francolinus-francolinus_2.html
# https://subspeciesmapper.netlify.app/Francolinus-francolinus_3.html
# https://subspeciesmapper.netlify.app/Campocolinus-coqui_4.html
# https://subspeciesmapper.netlify.app/Campocolinus-coqui_3.html
# https://subspeciesmapper.netlify.app/Campocolinus-coqui_2.html
# https://subspeciesmapper.netlify.app/Campocolinus-albogularis_4.html
# https://subspeciesmapper.netlify.app/Campocolinus-albogularis_3.html
# https://subspeciesmapper.netlify.app/Campocolinus-albogularis_2.html
# https://subspeciesmapper.netlify.app/Scleroptila-gutturalis_3.html
# https://subspeciesmapper.netlify.app/Scleroptila-gutturalis_2.html
# https://subspeciesmapper.netlify.app/Scleroptila-gutturalis_4.html
# https://subspeciesmapper.netlify.app/Alectoris-graeca_4.html
# https://subspeciesmapper.netlify.app/Alectoris-graeca_2.html
# https://subspeciesmapper.netlify.app/Alectoris-graeca_3.html
# https://subspeciesmapper.netlify.app/Pternistis-castaneicollis_4.html
# https://subspeciesmapper.netlify.app/Pternistis-castaneicollis_3.html
# https://subspeciesmapper.netlify.app/Pternistis-castaneicollis_2.html
# https://subspeciesmapper.netlify.app/Pternistis-afer_3.html
# https://subspeciesmapper.netlify.app/Pternistis-afer_2.html
# https://subspeciesmapper.netlify.app/Pternistis-afer_4.html
# https://subspeciesmapper.netlify.app/Columba-livia_2.html
# https://subspeciesmapper.netlify.app/Columba-livia_3.html
# https://subspeciesmapper.netlify.app/Columba-livia_4.html
# https://subspeciesmapper.netlify.app/Columba-palumbus_2.html
# https://subspeciesmapper.netlify.app/Columba-palumbus_3.html
# https://subspeciesmapper.netlify.app/Columba-palumbus_4.html
# https://subspeciesmapper.netlify.app/Columba-delegorguei_2.html
# https://subspeciesmapper.netlify.app/Columba-delegorguei_3.html
# https://subspeciesmapper.netlify.app/Columba-delegorguei_4.html
# https://subspeciesmapper.netlify.app/Columba-vitiensis_2.html
# https://subspeciesmapper.netlify.app/Columba-vitiensis_3.html
# https://subspeciesmapper.netlify.app/Columba-vitiensis_4.html
# https://subspeciesmapper.netlify.app/Aplopelia-larvata_3.html
# https://subspeciesmapper.netlify.app/Aplopelia-larvata_2.html
# https://subspeciesmapper.netlify.app/Aplopelia-larvata_4.html
# https://subspeciesmapper.netlify.app/Patagioenas-maculosa_3.html
# https://subspeciesmapper.netlify.app/Patagioenas-maculosa_2.html
# https://subspeciesmapper.netlify.app/Patagioenas-maculosa_4.html
# https://subspeciesmapper.netlify.app/Patagioenas-fasciata_4.html
# https://subspeciesmapper.netlify.app/Patagioenas-fasciata_2.html
# https://subspeciesmapper.netlify.app/Patagioenas-fasciata_3.html
# https://subspeciesmapper.netlify.app/Patagioenas-subvinacea_4.html
# https://subspeciesmapper.netlify.app/Patagioenas-subvinacea_3.html
# https://subspeciesmapper.netlify.app/Patagioenas-subvinacea_2.html
# https://subspeciesmapper.netlify.app/Spilopelia-chinensis_2.html
# https://subspeciesmapper.netlify.app/Spilopelia-chinensis_3.html
# https://subspeciesmapper.netlify.app/Spilopelia-chinensis_4.html
# https://subspeciesmapper.netlify.app/Macropygia-doreya_2.html
# https://subspeciesmapper.netlify.app/Macropygia-doreya_3.html
# https://subspeciesmapper.netlify.app/Macropygia-doreya_4.html
# https://subspeciesmapper.netlify.app/Macropygia-ruficeps_4.html
# https://subspeciesmapper.netlify.app/Macropygia-ruficeps_3.html
# https://subspeciesmapper.netlify.app/Macropygia-ruficeps_2.html
# https://subspeciesmapper.netlify.app/Pampusana-beccarii_4.html
# https://subspeciesmapper.netlify.app/Pampusana-beccarii_3.html
# https://subspeciesmapper.netlify.app/Pampusana-beccarii_2.html
# https://subspeciesmapper.netlify.app/Geophaps-plumifera_4.html
# https://subspeciesmapper.netlify.app/Geophaps-plumifera_2.html
# https://subspeciesmapper.netlify.app/Geophaps-plumifera_3.html
# https://subspeciesmapper.netlify.app/Geophaps-smithii_4.html
# https://subspeciesmapper.netlify.app/Geophaps-smithii_3.html
# https://subspeciesmapper.netlify.app/Geophaps-smithii_2.html
# https://subspeciesmapper.netlify.app/Geotrygon-montana_2.html
# https://subspeciesmapper.netlify.app/Geotrygon-montana_3.html
# https://subspeciesmapper.netlify.app/Geotrygon-montana_4.html
# https://subspeciesmapper.netlify.app/Leptotila-verreauxi_4.html
# https://subspeciesmapper.netlify.app/Leptotila-verreauxi_3.html
# https://subspeciesmapper.netlify.app/Leptotila-verreauxi_2.html
# https://subspeciesmapper.netlify.app/Leptotila-cassinii_3.html
# https://subspeciesmapper.netlify.app/Leptotila-cassinii_2.html
# https://subspeciesmapper.netlify.app/Leptotila-cassinii_4.html
# https://subspeciesmapper.netlify.app/Leptotila-plumbeiceps_4.html
# https://subspeciesmapper.netlify.app/Leptotila-plumbeiceps_2.html
# https://subspeciesmapper.netlify.app/Leptotila-plumbeiceps_3.html
# https://subspeciesmapper.netlify.app/Zentrygon-linearis_2.html
# https://subspeciesmapper.netlify.app/Zentrygon-linearis_3.html
# https://subspeciesmapper.netlify.app/Zentrygon-linearis_4.html
# https://subspeciesmapper.netlify.app/Otidiphaps-nobilis_4.html
# https://subspeciesmapper.netlify.app/Otidiphaps-nobilis_3.html
# https://subspeciesmapper.netlify.app/Otidiphaps-nobilis_2.html
# https://subspeciesmapper.netlify.app/Phapitreron-leucotis_3.html
# https://subspeciesmapper.netlify.app/Phapitreron-leucotis_2.html
# https://subspeciesmapper.netlify.app/Phapitreron-leucotis_4.html
# https://subspeciesmapper.netlify.app/Phapitreron-amethystinus_2.html
# https://subspeciesmapper.netlify.app/Phapitreron-amethystinus_3.html
# https://subspeciesmapper.netlify.app/Phapitreron-amethystinus_4.html
# https://subspeciesmapper.netlify.app/Treron-curvirostra_4.html
# https://subspeciesmapper.netlify.app/Treron-curvirostra_2.html
# https://subspeciesmapper.netlify.app/Treron-curvirostra_3.html
# https://subspeciesmapper.netlify.app/Treron-phoenicopterus_4.html
# https://subspeciesmapper.netlify.app/Treron-phoenicopterus_3.html
# https://subspeciesmapper.netlify.app/Treron-phoenicopterus_2.html
# https://subspeciesmapper.netlify.app/Treron-calvus_4.html
# https://subspeciesmapper.netlify.app/Treron-calvus_3.html
# https://subspeciesmapper.netlify.app/Treron-calvus_2.html
# https://subspeciesmapper.netlify.app/Treron-formosae_2.html
# https://subspeciesmapper.netlify.app/Treron-formosae_3.html
# https://subspeciesmapper.netlify.app/Treron-formosae_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-fischeri_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-fischeri_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-fischeri_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-ornatus_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-ornatus_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-ornatus_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-superbus_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-superbus_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-superbus_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-porphyraceus_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-porphyraceus_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-porphyraceus_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-regina_4.html
# https://subspeciesmapper.netlify.app/Ptilinopus-regina_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-regina_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-rivoli_3.html
# https://subspeciesmapper.netlify.app/Ptilinopus-rivoli_2.html
# https://subspeciesmapper.netlify.app/Ptilinopus-rivoli_4.html
# https://subspeciesmapper.netlify.app/Ducula-aenea_2.html
# https://subspeciesmapper.netlify.app/Ducula-aenea_3.html
# https://subspeciesmapper.netlify.app/Ducula-aenea_4.html
# https://subspeciesmapper.netlify.app/Ducula-rubricera_3.html
# https://subspeciesmapper.netlify.app/Ducula-rubricera_2.html
# https://subspeciesmapper.netlify.app/Ducula-rubricera_4.html
# https://subspeciesmapper.netlify.app/Ducula-basilica_2.html
# https://subspeciesmapper.netlify.app/Ducula-basilica_3.html
# https://subspeciesmapper.netlify.app/Ducula-basilica_4.html
# https://subspeciesmapper.netlify.app/Ducula-chalconota_4.html
# https://subspeciesmapper.netlify.app/Ducula-chalconota_2.html
# https://subspeciesmapper.netlify.app/Ducula-chalconota_3.html
# https://subspeciesmapper.netlify.app/Ducula-pinon_4.html
# https://subspeciesmapper.netlify.app/Ducula-pinon_2.html
# https://subspeciesmapper.netlify.app/Ducula-pinon_3.html
# https://subspeciesmapper.netlify.app/Ducula-lacernulata_3.html
# https://subspeciesmapper.netlify.app/Ducula-lacernulata_2.html
# https://subspeciesmapper.netlify.app/Ducula-lacernulata_4.html
# https://subspeciesmapper.netlify.app/Hemiphaga-novaeseelandiae_3.html
# https://subspeciesmapper.netlify.app/Hemiphaga-novaeseelandiae_2.html
# https://subspeciesmapper.netlify.app/Hemiphaga-novaeseelandiae_4.html
# https://subspeciesmapper.netlify.app/Pterocles-alchata_4.html
# https://subspeciesmapper.netlify.app/Pterocles-alchata_3.html
# https://subspeciesmapper.netlify.app/Pterocles-alchata_2.html
# https://subspeciesmapper.netlify.app/Pterocles-exustus_4.html
# https://subspeciesmapper.netlify.app/Pterocles-exustus_2.html
# https://subspeciesmapper.netlify.app/Pterocles-exustus_3.html
# https://subspeciesmapper.netlify.app/Pterocles-lichtensteinii_2.html
# https://subspeciesmapper.netlify.app/Pterocles-lichtensteinii_3.html
# https://subspeciesmapper.netlify.app/Pterocles-lichtensteinii_4.html
# https://subspeciesmapper.netlify.app/Chlamydotis-undulata_2.html
# https://subspeciesmapper.netlify.app/Chlamydotis-undulata_3.html
# https://subspeciesmapper.netlify.app/Chlamydotis-undulata_4.html
# https://subspeciesmapper.netlify.app/Neotis-denhami_4.html
# https://subspeciesmapper.netlify.app/Neotis-denhami_2.html
# https://subspeciesmapper.netlify.app/Neotis-denhami_3.html
# https://subspeciesmapper.netlify.app/Eupodotis-senegalensis_4.html
# https://subspeciesmapper.netlify.app/Eupodotis-senegalensis_2.html
# https://subspeciesmapper.netlify.app/Eupodotis-senegalensis_3.html
# https://subspeciesmapper.netlify.app/Crinifer-personatus_3.html
# https://subspeciesmapper.netlify.app/Crinifer-personatus_2.html
# https://subspeciesmapper.netlify.app/Crinifer-personatus_4.html
# https://subspeciesmapper.netlify.app/Gallirex-johnstoni_4.html
# https://subspeciesmapper.netlify.app/Gallirex-johnstoni_3.html
# https://subspeciesmapper.netlify.app/Gallirex-johnstoni_2.html
# https://subspeciesmapper.netlify.app/Menelikornis-leucotis_3.html
# https://subspeciesmapper.netlify.app/Menelikornis-leucotis_2.html
# https://subspeciesmapper.netlify.app/Menelikornis-leucotis_4.html
# https://subspeciesmapper.netlify.app/Tauraco-macrorhynchus_4.html
# https://subspeciesmapper.netlify.app/Tauraco-macrorhynchus_3.html
# https://subspeciesmapper.netlify.app/Tauraco-macrorhynchus_2.html
# https://subspeciesmapper.netlify.app/Tauraco-schuettii_4.html
# https://subspeciesmapper.netlify.app/Tauraco-schuettii_2.html
# https://subspeciesmapper.netlify.app/Tauraco-schuettii_3.html
# https://subspeciesmapper.netlify.app/Tauraco-persa_4.html
# https://subspeciesmapper.netlify.app/Tauraco-persa_2.html
# https://subspeciesmapper.netlify.app/Tauraco-persa_3.html
# https://subspeciesmapper.netlify.app/Tauraco-fischeri_4.html
# https://subspeciesmapper.netlify.app/Tauraco-fischeri_2.html
# https://subspeciesmapper.netlify.app/Tauraco-fischeri_3.html
# https://subspeciesmapper.netlify.app/Tauraco-corythaix_2.html
# https://subspeciesmapper.netlify.app/Tauraco-corythaix_3.html
# https://subspeciesmapper.netlify.app/Tauraco-corythaix_4.html
# https://subspeciesmapper.netlify.app/Coua-cristata_4.html
# https://subspeciesmapper.netlify.app/Coua-cristata_2.html
# https://subspeciesmapper.netlify.app/Coua-cristata_3.html
# https://subspeciesmapper.netlify.app/Centropus-sinensis_2.html
# https://subspeciesmapper.netlify.app/Centropus-sinensis_3.html
# https://subspeciesmapper.netlify.app/Centropus-sinensis_4.html
# https://subspeciesmapper.netlify.app/Centropus-phasianinus_3.html
# https://subspeciesmapper.netlify.app/Centropus-phasianinus_2.html
# https://subspeciesmapper.netlify.app/Centropus-phasianinus_4.html
# https://subspeciesmapper.netlify.app/Piaya-cayana_2.html
# https://subspeciesmapper.netlify.app/Piaya-cayana_3.html
# https://subspeciesmapper.netlify.app/Piaya-cayana_4.html
# https://subspeciesmapper.netlify.app/Coccyzus-merlini_4.html
# https://subspeciesmapper.netlify.app/Coccyzus-merlini_2.html
# https://subspeciesmapper.netlify.app/Coccyzus-merlini_3.html
# https://subspeciesmapper.netlify.app/Pachycoccyx-audeberti_4.html
# https://subspeciesmapper.netlify.app/Pachycoccyx-audeberti_3.html
# https://subspeciesmapper.netlify.app/Pachycoccyx-audeberti_2.html
# https://subspeciesmapper.netlify.app/Eudynamys-orientalis_3.html
# https://subspeciesmapper.netlify.app/Eudynamys-orientalis_2.html
# https://subspeciesmapper.netlify.app/Eudynamys-orientalis_4.html
# https://subspeciesmapper.netlify.app/Chrysococcyx-cupreus_4.html
# https://subspeciesmapper.netlify.app/Chrysococcyx-cupreus_2.html
# https://subspeciesmapper.netlify.app/Chrysococcyx-cupreus_3.html
# https://subspeciesmapper.netlify.app/Chalcites-lucidus_3.html
# https://subspeciesmapper.netlify.app/Chalcites-lucidus_2.html
# https://subspeciesmapper.netlify.app/Chalcites-lucidus_4.html
# https://subspeciesmapper.netlify.app/Chalcites-minutillus_3.html
# https://subspeciesmapper.netlify.app/Chalcites-minutillus_2.html
# https://subspeciesmapper.netlify.app/Chalcites-minutillus_4.html
# https://subspeciesmapper.netlify.app/Cacomantis-flabelliformis_3.html
# https://subspeciesmapper.netlify.app/Cacomantis-flabelliformis_2.html
# https://subspeciesmapper.netlify.app/Cacomantis-flabelliformis_4.html
# https://subspeciesmapper.netlify.app/Cercococcyx-montanus_4.html
# https://subspeciesmapper.netlify.app/Cercococcyx-montanus_2.html
# https://subspeciesmapper.netlify.app/Cercococcyx-montanus_3.html
# https://subspeciesmapper.netlify.app/Cuculus-clamosus_2.html
# https://subspeciesmapper.netlify.app/Cuculus-clamosus_3.html
# https://subspeciesmapper.netlify.app/Cuculus-clamosus_4.html
# https://subspeciesmapper.netlify.app/Lyncornis-macrotis_4.html
# https://subspeciesmapper.netlify.app/Lyncornis-macrotis_3.html
# https://subspeciesmapper.netlify.app/Lyncornis-macrotis_2.html
# https://subspeciesmapper.netlify.app/Lurocalis-semitorquatus_4.html
# https://subspeciesmapper.netlify.app/Lurocalis-semitorquatus_2.html
# https://subspeciesmapper.netlify.app/Lurocalis-semitorquatus_3.html
# https://subspeciesmapper.netlify.app/Nyctiprogne-leucopyga_3.html
# https://subspeciesmapper.netlify.app/Nyctiprogne-leucopyga_2.html
# https://subspeciesmapper.netlify.app/Nyctiprogne-leucopyga_4.html
# https://subspeciesmapper.netlify.app/Systellura-longirostris_2.html
# https://subspeciesmapper.netlify.app/Systellura-longirostris_3.html
# https://subspeciesmapper.netlify.app/Systellura-longirostris_4.html
# https://subspeciesmapper.netlify.app/Antrostomus-rufus_4.html
# https://subspeciesmapper.netlify.app/Antrostomus-rufus_2.html
# https://subspeciesmapper.netlify.app/Antrostomus-rufus_3.html
# https://subspeciesmapper.netlify.app/Caprimulgus-nubicus_3.html
# https://subspeciesmapper.netlify.app/Caprimulgus-nubicus_2.html
# https://subspeciesmapper.netlify.app/Caprimulgus-nubicus_4.html
# https://subspeciesmapper.netlify.app/Caprimulgus-pectoralis_4.html
# https://subspeciesmapper.netlify.app/Caprimulgus-pectoralis_3.html
# https://subspeciesmapper.netlify.app/Caprimulgus-pectoralis_2.html
# https://subspeciesmapper.netlify.app/Caprimulgus-poliocephalus_4.html
# https://subspeciesmapper.netlify.app/Caprimulgus-poliocephalus_2.html
# https://subspeciesmapper.netlify.app/Caprimulgus-poliocephalus_3.html
# https://subspeciesmapper.netlify.app/Caprimulgus-affinis_2.html
# https://subspeciesmapper.netlify.app/Caprimulgus-affinis_3.html
# https://subspeciesmapper.netlify.app/Caprimulgus-affinis_4.html
# https://subspeciesmapper.netlify.app/Nyctibius-jamaicensis_3.html
# https://subspeciesmapper.netlify.app/Nyctibius-jamaicensis_2.html
# https://subspeciesmapper.netlify.app/Nyctibius-jamaicensis_4.html
# https://subspeciesmapper.netlify.app/Podargus-ocellatus_4.html
# https://subspeciesmapper.netlify.app/Podargus-ocellatus_2.html
# https://subspeciesmapper.netlify.app/Podargus-ocellatus_3.html
# https://subspeciesmapper.netlify.app/Batrachostomus-affinis_4.html
# https://subspeciesmapper.netlify.app/Batrachostomus-affinis_2.html
# https://subspeciesmapper.netlify.app/Batrachostomus-affinis_3.html
# https://subspeciesmapper.netlify.app/Aegotheles-bennettii_3.html
# https://subspeciesmapper.netlify.app/Aegotheles-bennettii_2.html
# https://subspeciesmapper.netlify.app/Aegotheles-bennettii_4.html
# https://subspeciesmapper.netlify.app/Cypseloides-niger_4.html
# https://subspeciesmapper.netlify.app/Cypseloides-niger_3.html
# https://subspeciesmapper.netlify.app/Cypseloides-niger_2.html
# https://subspeciesmapper.netlify.app/Chaetura-cinereiventris_4.html
# https://subspeciesmapper.netlify.app/Chaetura-cinereiventris_3.html
# https://subspeciesmapper.netlify.app/Chaetura-cinereiventris_2.html
# https://subspeciesmapper.netlify.app/Chaetura-spinicaudus_3.html
# https://subspeciesmapper.netlify.app/Chaetura-spinicaudus_2.html
# https://subspeciesmapper.netlify.app/Chaetura-spinicaudus_4.html
# https://subspeciesmapper.netlify.app/Chaetura-vauxi_2.html
# https://subspeciesmapper.netlify.app/Chaetura-vauxi_3.html
# https://subspeciesmapper.netlify.app/Chaetura-vauxi_4.html
# https://subspeciesmapper.netlify.app/Chaetura-brachyura_3.html
# https://subspeciesmapper.netlify.app/Chaetura-brachyura_2.html
# https://subspeciesmapper.netlify.app/Chaetura-brachyura_4.html
# https://subspeciesmapper.netlify.app/Hirundapus-caudacutus_4.html
# https://subspeciesmapper.netlify.app/Hirundapus-caudacutus_2.html
# https://subspeciesmapper.netlify.app/Hirundapus-caudacutus_3.html
# https://subspeciesmapper.netlify.app/Aerodramus-brevirostris_3.html
# https://subspeciesmapper.netlify.app/Aerodramus-brevirostris_2.html
# https://subspeciesmapper.netlify.app/Aerodramus-brevirostris_4.html
# https://subspeciesmapper.netlify.app/Aerodramus-fuciphagus_2.html
# https://subspeciesmapper.netlify.app/Aerodramus-fuciphagus_3.html
# https://subspeciesmapper.netlify.app/Aerodramus-fuciphagus_4.html
# https://subspeciesmapper.netlify.app/Apus-barbatus_3.html
# https://subspeciesmapper.netlify.app/Apus-barbatus_2.html
# https://subspeciesmapper.netlify.app/Apus-barbatus_4.html
# https://subspeciesmapper.netlify.app/Apus-affinis_4.html
# https://subspeciesmapper.netlify.app/Apus-affinis_2.html
# https://subspeciesmapper.netlify.app/Apus-affinis_3.html
# https://subspeciesmapper.netlify.app/Apus-horus_4.html
# https://subspeciesmapper.netlify.app/Apus-horus_3.html
# https://subspeciesmapper.netlify.app/Apus-horus_2.html
# https://subspeciesmapper.netlify.app/Cypsiurus-gracilis_4.html
# https://subspeciesmapper.netlify.app/Cypsiurus-gracilis_3.html
# https://subspeciesmapper.netlify.app/Cypsiurus-gracilis_2.html
# https://subspeciesmapper.netlify.app/Threnetes-niger_4.html
# https://subspeciesmapper.netlify.app/Threnetes-niger_3.html
# https://subspeciesmapper.netlify.app/Threnetes-niger_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-bourcieri_3.html
# https://subspeciesmapper.netlify.app/Phaethornis-bourcieri_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-bourcieri_4.html
# https://subspeciesmapper.netlify.app/Phaethornis-longirostris_4.html
# https://subspeciesmapper.netlify.app/Phaethornis-longirostris_3.html
# https://subspeciesmapper.netlify.app/Phaethornis-longirostris_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-mexicanus_3.html
# https://subspeciesmapper.netlify.app/Phaethornis-mexicanus_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-mexicanus_4.html
# https://subspeciesmapper.netlify.app/Phaethornis-malaris_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-malaris_3.html
# https://subspeciesmapper.netlify.app/Phaethornis-malaris_4.html
# https://subspeciesmapper.netlify.app/Phaethornis-griseogularis_2.html
# https://subspeciesmapper.netlify.app/Phaethornis-griseogularis_3.html
# https://subspeciesmapper.netlify.app/Phaethornis-griseogularis_4.html
# https://subspeciesmapper.netlify.app/Colibri-cyanotus_3.html
# https://subspeciesmapper.netlify.app/Colibri-cyanotus_2.html
# https://subspeciesmapper.netlify.app/Colibri-cyanotus_4.html
# https://subspeciesmapper.netlify.app/Anthracothorax-nigricollis_2.html
# https://subspeciesmapper.netlify.app/Anthracothorax-nigricollis_3.html
# https://subspeciesmapper.netlify.app/Anthracothorax-nigricollis_4.html
# https://subspeciesmapper.netlify.app/Heliangelus-viola_3.html
# https://subspeciesmapper.netlify.app/Heliangelus-viola_2.html
# https://subspeciesmapper.netlify.app/Heliangelus-viola_4.html
# https://subspeciesmapper.netlify.app/Adelomyia-melanogenys_4.html
# https://subspeciesmapper.netlify.app/Adelomyia-melanogenys_2.html
# https://subspeciesmapper.netlify.app/Adelomyia-melanogenys_3.html
# https://subspeciesmapper.netlify.app/Oreonympha-nobilis_4.html
# https://subspeciesmapper.netlify.app/Oreonympha-nobilis_3.html
# https://subspeciesmapper.netlify.app/Oreonympha-nobilis_2.html
# https://subspeciesmapper.netlify.app/Metallura-tyrianthina_3.html
# https://subspeciesmapper.netlify.app/Metallura-tyrianthina_2.html
# https://subspeciesmapper.netlify.app/Metallura-tyrianthina_4.html
# https://subspeciesmapper.netlify.app/Metallura-williami_2.html
# https://subspeciesmapper.netlify.app/Metallura-williami_3.html
# https://subspeciesmapper.netlify.app/Metallura-williami_4.html
# https://subspeciesmapper.netlify.app/Eriocnemis-luciani_4.html
# https://subspeciesmapper.netlify.app/Eriocnemis-luciani_3.html
# https://subspeciesmapper.netlify.app/Eriocnemis-luciani_2.html
# https://subspeciesmapper.netlify.app/Coeligena-torquata_3.html
# https://subspeciesmapper.netlify.app/Coeligena-torquata_2.html
# https://subspeciesmapper.netlify.app/Coeligena-torquata_4.html
# https://subspeciesmapper.netlify.app/Coeligena-violifer_2.html
# https://subspeciesmapper.netlify.app/Coeligena-violifer_3.html
# https://subspeciesmapper.netlify.app/Coeligena-violifer_4.html
# https://subspeciesmapper.netlify.app/Ocreatus-addae_4.html
# https://subspeciesmapper.netlify.app/Ocreatus-addae_3.html
# https://subspeciesmapper.netlify.app/Ocreatus-addae_2.html
# https://subspeciesmapper.netlify.app/Heliodoxa-schreibersii_2.html
# https://subspeciesmapper.netlify.app/Heliodoxa-schreibersii_3.html
# https://subspeciesmapper.netlify.app/Heliodoxa-schreibersii_4.html
# https://subspeciesmapper.netlify.app/Patagona-gigas_2.html
# https://subspeciesmapper.netlify.app/Patagona-gigas_3.html
# https://subspeciesmapper.netlify.app/Patagona-gigas_4.html
# https://subspeciesmapper.netlify.app/Lampornis-amethystinus_4.html
# https://subspeciesmapper.netlify.app/Lampornis-amethystinus_2.html
# https://subspeciesmapper.netlify.app/Lampornis-amethystinus_3.html
# https://subspeciesmapper.netlify.app/Lampornis-castaneoventris_2.html
# https://subspeciesmapper.netlify.app/Lampornis-castaneoventris_3.html
# https://subspeciesmapper.netlify.app/Lampornis-castaneoventris_4.html
# https://subspeciesmapper.netlify.app/Selasphorus-flammula_2.html
# https://subspeciesmapper.netlify.app/Selasphorus-flammula_3.html
# https://subspeciesmapper.netlify.app/Selasphorus-flammula_4.html
# https://subspeciesmapper.netlify.app/Cynanthus-canivetii_4.html
# https://subspeciesmapper.netlify.app/Cynanthus-canivetii_3.html
# https://subspeciesmapper.netlify.app/Cynanthus-canivetii_2.html
# https://subspeciesmapper.netlify.app/Pampa-curvipennis_4.html
# https://subspeciesmapper.netlify.app/Pampa-curvipennis_2.html
# https://subspeciesmapper.netlify.app/Pampa-curvipennis_3.html
# https://subspeciesmapper.netlify.app/Orthorhyncus-cristatus_4.html
# https://subspeciesmapper.netlify.app/Orthorhyncus-cristatus_3.html
# https://subspeciesmapper.netlify.app/Orthorhyncus-cristatus_2.html
# https://subspeciesmapper.netlify.app/Campylopterus-largipennis_4.html
# https://subspeciesmapper.netlify.app/Campylopterus-largipennis_2.html
# https://subspeciesmapper.netlify.app/Campylopterus-largipennis_3.html
# https://subspeciesmapper.netlify.app/Chalybura-buffonii_2.html
# https://subspeciesmapper.netlify.app/Chalybura-buffonii_3.html
# https://subspeciesmapper.netlify.app/Chalybura-buffonii_4.html
# https://subspeciesmapper.netlify.app/Thalurania-colombica_4.html
# https://subspeciesmapper.netlify.app/Thalurania-colombica_3.html
# https://subspeciesmapper.netlify.app/Thalurania-colombica_2.html
# https://subspeciesmapper.netlify.app/Phaeochroa-cuvierii_4.html
# https://subspeciesmapper.netlify.app/Phaeochroa-cuvierii_2.html
# https://subspeciesmapper.netlify.app/Phaeochroa-cuvierii_3.html
# https://subspeciesmapper.netlify.app/Ramosomyia-viridifrons_4.html
# https://subspeciesmapper.netlify.app/Ramosomyia-viridifrons_2.html
# https://subspeciesmapper.netlify.app/Ramosomyia-viridifrons_3.html
# https://subspeciesmapper.netlify.app/Saucerottia-cyanocephala_4.html
# https://subspeciesmapper.netlify.app/Saucerottia-cyanocephala_3.html
# https://subspeciesmapper.netlify.app/Saucerottia-cyanocephala_2.html
# https://subspeciesmapper.netlify.app/Saucerottia-beryllina_4.html
# https://subspeciesmapper.netlify.app/Saucerottia-beryllina_3.html
# https://subspeciesmapper.netlify.app/Saucerottia-beryllina_2.html
# https://subspeciesmapper.netlify.app/Amazilia-rutila_4.html
# https://subspeciesmapper.netlify.app/Amazilia-rutila_2.html
# https://subspeciesmapper.netlify.app/Amazilia-rutila_3.html
# https://subspeciesmapper.netlify.app/Amazilia-yucatanensis_4.html
# https://subspeciesmapper.netlify.app/Amazilia-yucatanensis_3.html
# https://subspeciesmapper.netlify.app/Amazilia-yucatanensis_2.html
# https://subspeciesmapper.netlify.app/Amazilia-tzacatl_3.html
# https://subspeciesmapper.netlify.app/Amazilia-tzacatl_2.html
# https://subspeciesmapper.netlify.app/Amazilia-tzacatl_4.html
# https://subspeciesmapper.netlify.app/Amazilis-amazilia_4.html
# https://subspeciesmapper.netlify.app/Amazilis-amazilia_3.html
# https://subspeciesmapper.netlify.app/Amazilis-amazilia_2.html
# https://subspeciesmapper.netlify.app/Chrysuronia-versicolor_3.html
# https://subspeciesmapper.netlify.app/Chrysuronia-versicolor_2.html
# https://subspeciesmapper.netlify.app/Chrysuronia-versicolor_4.html
# https://subspeciesmapper.netlify.app/Chionomesa-lactea_4.html
# https://subspeciesmapper.netlify.app/Chionomesa-lactea_2.html
# https://subspeciesmapper.netlify.app/Chionomesa-lactea_3.html
# https://subspeciesmapper.netlify.app/Elliotomyia-chionogaster_3.html
# https://subspeciesmapper.netlify.app/Elliotomyia-chionogaster_2.html
# https://subspeciesmapper.netlify.app/Elliotomyia-chionogaster_4.html
# https://subspeciesmapper.netlify.app/Sarothrura-pulchra_3.html
# https://subspeciesmapper.netlify.app/Sarothrura-pulchra_2.html
# https://subspeciesmapper.netlify.app/Sarothrura-pulchra_4.html
# https://subspeciesmapper.netlify.app/Rallus-obsoletus_3.html
# https://subspeciesmapper.netlify.app/Rallus-obsoletus_2.html
# https://subspeciesmapper.netlify.app/Rallus-obsoletus_4.html
# https://subspeciesmapper.netlify.app/Rallus-longirostris_3.html
# https://subspeciesmapper.netlify.app/Rallus-longirostris_2.html
# https://subspeciesmapper.netlify.app/Rallus-longirostris_4.html
# https://subspeciesmapper.netlify.app/Rallus-elegans_2.html
# https://subspeciesmapper.netlify.app/Rallus-elegans_3.html
# https://subspeciesmapper.netlify.app/Rallus-elegans_4.html
# https://subspeciesmapper.netlify.app/Rallus-crepitans_2.html
# https://subspeciesmapper.netlify.app/Rallus-crepitans_3.html
# https://subspeciesmapper.netlify.app/Rallus-crepitans_4.html
# https://subspeciesmapper.netlify.app/Gallirallus-woodfordi_3.html
# https://subspeciesmapper.netlify.app/Gallirallus-woodfordi_2.html
# https://subspeciesmapper.netlify.app/Gallirallus-woodfordi_4.html
# https://subspeciesmapper.netlify.app/Aramides-cajaneus_2.html
# https://subspeciesmapper.netlify.app/Aramides-cajaneus_3.html
# https://subspeciesmapper.netlify.app/Aramides-cajaneus_4.html
# https://subspeciesmapper.netlify.app/Gallinula-galeata_2.html
# https://subspeciesmapper.netlify.app/Gallinula-galeata_3.html
# https://subspeciesmapper.netlify.app/Gallinula-galeata_4.html
# https://subspeciesmapper.netlify.app/Fulica-alai_4.html
# https://subspeciesmapper.netlify.app/Fulica-alai_3.html
# https://subspeciesmapper.netlify.app/Fulica-alai_2.html
# https://subspeciesmapper.netlify.app/Fulica-americana_4.html
# https://subspeciesmapper.netlify.app/Fulica-americana_3.html
# https://subspeciesmapper.netlify.app/Fulica-americana_2.html
# https://subspeciesmapper.netlify.app/Fulica-ardesiaca_2.html
# https://subspeciesmapper.netlify.app/Fulica-ardesiaca_3.html
# https://subspeciesmapper.netlify.app/Fulica-ardesiaca_4.html
# https://subspeciesmapper.netlify.app/Zapornia-pusilla_2.html
# https://subspeciesmapper.netlify.app/Zapornia-pusilla_3.html
# https://subspeciesmapper.netlify.app/Zapornia-pusilla_4.html
# https://subspeciesmapper.netlify.app/Coturnicops-noveboracensis_2.html
# https://subspeciesmapper.netlify.app/Coturnicops-noveboracensis_3.html
# https://subspeciesmapper.netlify.app/Coturnicops-noveboracensis_4.html
# https://subspeciesmapper.netlify.app/Laterallus-albigularis_4.html
# https://subspeciesmapper.netlify.app/Laterallus-albigularis_3.html
# https://subspeciesmapper.netlify.app/Laterallus-albigularis_2.html
# https://subspeciesmapper.netlify.app/Laterallus-jamaicensis_2.html
# https://subspeciesmapper.netlify.app/Laterallus-jamaicensis_3.html
# https://subspeciesmapper.netlify.app/Laterallus-jamaicensis_4.html
# https://subspeciesmapper.netlify.app/Aramus-guarauna_3.html
# https://subspeciesmapper.netlify.app/Aramus-guarauna_2.html
# https://subspeciesmapper.netlify.app/Aramus-guarauna_4.html
# https://subspeciesmapper.netlify.app/Psophia-crepitans_4.html
# https://subspeciesmapper.netlify.app/Psophia-crepitans_3.html
# https://subspeciesmapper.netlify.app/Psophia-crepitans_2.html
# https://subspeciesmapper.netlify.app/Psophia-viridis_3.html
# https://subspeciesmapper.netlify.app/Psophia-viridis_2.html
# https://subspeciesmapper.netlify.app/Psophia-viridis_4.html
# https://subspeciesmapper.netlify.app/Antigone-canadensis_4.html
# https://subspeciesmapper.netlify.app/Antigone-canadensis_2.html
# https://subspeciesmapper.netlify.app/Antigone-canadensis_3.html
# https://subspeciesmapper.netlify.app/Himantopus-mexicanus_3.html
# https://subspeciesmapper.netlify.app/Himantopus-mexicanus_2.html
# https://subspeciesmapper.netlify.app/Himantopus-mexicanus_4.html
# https://subspeciesmapper.netlify.app/Haematopus-ostralegus_4.html
# https://subspeciesmapper.netlify.app/Haematopus-ostralegus_3.html
# https://subspeciesmapper.netlify.app/Haematopus-ostralegus_2.html
# https://subspeciesmapper.netlify.app/Thinornis-tricollaris_4.html
# https://subspeciesmapper.netlify.app/Thinornis-tricollaris_3.html
# https://subspeciesmapper.netlify.app/Thinornis-tricollaris_2.html
# https://subspeciesmapper.netlify.app/Thinornis-dubius_2.html
# https://subspeciesmapper.netlify.app/Thinornis-dubius_3.html
# https://subspeciesmapper.netlify.app/Thinornis-dubius_4.html
# https://subspeciesmapper.netlify.app/Vanellus-indicus_4.html
# https://subspeciesmapper.netlify.app/Vanellus-indicus_2.html
# https://subspeciesmapper.netlify.app/Vanellus-indicus_3.html
# https://subspeciesmapper.netlify.app/Vanellus-miles_2.html
# https://subspeciesmapper.netlify.app/Vanellus-miles_3.html
# https://subspeciesmapper.netlify.app/Vanellus-miles_4.html
# https://subspeciesmapper.netlify.app/Vanellus-chilensis_2.html
# https://subspeciesmapper.netlify.app/Vanellus-chilensis_3.html
# https://subspeciesmapper.netlify.app/Vanellus-chilensis_4.html
# https://subspeciesmapper.netlify.app/Anarhynchus-obscurus_2.html
# https://subspeciesmapper.netlify.app/Anarhynchus-obscurus_3.html
# https://subspeciesmapper.netlify.app/Anarhynchus-obscurus_4.html
# https://subspeciesmapper.netlify.app/Anarhynchus-nivosus_4.html
# https://subspeciesmapper.netlify.app/Anarhynchus-nivosus_2.html
# https://subspeciesmapper.netlify.app/Anarhynchus-nivosus_3.html
# https://subspeciesmapper.netlify.app/Anarhynchus-alexandrinus_4.html
# https://subspeciesmapper.netlify.app/Anarhynchus-alexandrinus_3.html
# https://subspeciesmapper.netlify.app/Anarhynchus-alexandrinus_2.html
# https://subspeciesmapper.netlify.app/Jacana-jacana_2.html
# https://subspeciesmapper.netlify.app/Jacana-jacana_3.html
# https://subspeciesmapper.netlify.app/Jacana-jacana_4.html
# https://subspeciesmapper.netlify.app/Numenius-phaeopus_4.html
# https://subspeciesmapper.netlify.app/Numenius-phaeopus_3.html
# https://subspeciesmapper.netlify.app/Numenius-phaeopus_2.html
# https://subspeciesmapper.netlify.app/Limosa-lapponica_4.html
# https://subspeciesmapper.netlify.app/Limosa-lapponica_3.html
# https://subspeciesmapper.netlify.app/Limosa-lapponica_2.html
# https://subspeciesmapper.netlify.app/Limosa-limosa_4.html
# https://subspeciesmapper.netlify.app/Limosa-limosa_3.html
# https://subspeciesmapper.netlify.app/Limosa-limosa_2.html
# https://subspeciesmapper.netlify.app/Limnodromus-griseus_4.html
# https://subspeciesmapper.netlify.app/Limnodromus-griseus_2.html
# https://subspeciesmapper.netlify.app/Limnodromus-griseus_3.html
# https://subspeciesmapper.netlify.app/Tringa-solitaria_2.html
# https://subspeciesmapper.netlify.app/Tringa-solitaria_3.html
# https://subspeciesmapper.netlify.app/Tringa-solitaria_4.html
# https://subspeciesmapper.netlify.app/Tringa-semipalmata_4.html
# https://subspeciesmapper.netlify.app/Tringa-semipalmata_3.html
# https://subspeciesmapper.netlify.app/Tringa-semipalmata_2.html
# https://subspeciesmapper.netlify.app/Calidris-alpina_4.html
# https://subspeciesmapper.netlify.app/Calidris-alpina_3.html
# https://subspeciesmapper.netlify.app/Calidris-alpina_2.html
# https://subspeciesmapper.netlify.app/Calidris-ptilocnemis_4.html
# https://subspeciesmapper.netlify.app/Calidris-ptilocnemis_2.html
# https://subspeciesmapper.netlify.app/Calidris-ptilocnemis_3.html
# https://subspeciesmapper.netlify.app/Glareola-nuchalis_4.html
# https://subspeciesmapper.netlify.app/Glareola-nuchalis_3.html
# https://subspeciesmapper.netlify.app/Glareola-nuchalis_2.html
# https://subspeciesmapper.netlify.app/Stercorarius-antarcticus_3.html
# https://subspeciesmapper.netlify.app/Stercorarius-antarcticus_2.html
# https://subspeciesmapper.netlify.app/Stercorarius-antarcticus_4.html
# https://subspeciesmapper.netlify.app/Cepphus-grylle_4.html
# https://subspeciesmapper.netlify.app/Cepphus-grylle_2.html
# https://subspeciesmapper.netlify.app/Cepphus-grylle_3.html
# https://subspeciesmapper.netlify.app/Cepphus-columba_2.html
# https://subspeciesmapper.netlify.app/Cepphus-columba_3.html
# https://subspeciesmapper.netlify.app/Cepphus-columba_4.html
# https://subspeciesmapper.netlify.app/Rissa-tridactyla_4.html
# https://subspeciesmapper.netlify.app/Rissa-tridactyla_3.html
# https://subspeciesmapper.netlify.app/Rissa-tridactyla_2.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-novaehollandiae_4.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-novaehollandiae_3.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-novaehollandiae_2.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-maculipennis_2.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-maculipennis_3.html
# https://subspeciesmapper.netlify.app/Chroicocephalus-maculipennis_4.html
# https://subspeciesmapper.netlify.app/Larus-canus_4.html
# https://subspeciesmapper.netlify.app/Larus-canus_2.html
# https://subspeciesmapper.netlify.app/Larus-canus_3.html
# https://subspeciesmapper.netlify.app/Larus-dominicanus_4.html
# https://subspeciesmapper.netlify.app/Larus-dominicanus_3.html
# https://subspeciesmapper.netlify.app/Larus-dominicanus_2.html
# https://subspeciesmapper.netlify.app/Larus-michahellis_4.html
# https://subspeciesmapper.netlify.app/Larus-michahellis_3.html
# https://subspeciesmapper.netlify.app/Larus-michahellis_2.html
# https://subspeciesmapper.netlify.app/Larus-fuscus_3.html
# https://subspeciesmapper.netlify.app/Larus-fuscus_2.html
# https://subspeciesmapper.netlify.app/Larus-fuscus_4.html
# https://subspeciesmapper.netlify.app/Larus-californicus_3.html
# https://subspeciesmapper.netlify.app/Larus-californicus_2.html
# https://subspeciesmapper.netlify.app/Larus-californicus_4.html
# https://subspeciesmapper.netlify.app/Larus-glaucoides_4.html
# https://subspeciesmapper.netlify.app/Larus-glaucoides_2.html
# https://subspeciesmapper.netlify.app/Larus-glaucoides_3.html
# https://subspeciesmapper.netlify.app/Rynchops-niger_4.html
# https://subspeciesmapper.netlify.app/Rynchops-niger_2.html
# https://subspeciesmapper.netlify.app/Rynchops-niger_3.html
# https://subspeciesmapper.netlify.app/Gygis-alba_4.html
# https://subspeciesmapper.netlify.app/Gygis-alba_2.html
# https://subspeciesmapper.netlify.app/Gygis-alba_3.html
# https://subspeciesmapper.netlify.app/Anous-minutus_4.html
# https://subspeciesmapper.netlify.app/Anous-minutus_2.html
# https://subspeciesmapper.netlify.app/Anous-minutus_3.html
# https://subspeciesmapper.netlify.app/Chlidonias-niger_2.html
# https://subspeciesmapper.netlify.app/Chlidonias-niger_3.html
# https://subspeciesmapper.netlify.app/Chlidonias-niger_4.html
# https://subspeciesmapper.netlify.app/Sterna-vittata_4.html
# https://subspeciesmapper.netlify.app/Sterna-vittata_3.html
# https://subspeciesmapper.netlify.app/Sterna-vittata_2.html
# https://subspeciesmapper.netlify.app/Sterna-hirundo_3.html
# https://subspeciesmapper.netlify.app/Sterna-hirundo_2.html
# https://subspeciesmapper.netlify.app/Sterna-hirundo_4.html
# https://subspeciesmapper.netlify.app/Thalasseus-sandvicensis_4.html
# https://subspeciesmapper.netlify.app/Thalasseus-sandvicensis_3.html
# https://subspeciesmapper.netlify.app/Thalasseus-sandvicensis_2.html
# https://subspeciesmapper.netlify.app/Tachybaptus-ruficollis_4.html
# https://subspeciesmapper.netlify.app/Tachybaptus-ruficollis_3.html
# https://subspeciesmapper.netlify.app/Tachybaptus-ruficollis_2.html
# https://subspeciesmapper.netlify.app/Podiceps-occipitalis_2.html
# https://subspeciesmapper.netlify.app/Podiceps-occipitalis_3.html
# https://subspeciesmapper.netlify.app/Podiceps-occipitalis_4.html
# https://subspeciesmapper.netlify.app/Eurypyga-helias_4.html
# https://subspeciesmapper.netlify.app/Eurypyga-helias_2.html
# https://subspeciesmapper.netlify.app/Eurypyga-helias_3.html
# https://subspeciesmapper.netlify.app/Phaethon-lepturus_3.html
# https://subspeciesmapper.netlify.app/Phaethon-lepturus_2.html
# https://subspeciesmapper.netlify.app/Phaethon-lepturus_4.html
# https://subspeciesmapper.netlify.app/Eudyptes-chrysocome_4.html
# https://subspeciesmapper.netlify.app/Eudyptes-chrysocome_3.html
# https://subspeciesmapper.netlify.app/Eudyptes-chrysocome_2.html
# https://subspeciesmapper.netlify.app/Diomedea-antipodensis_3.html
# https://subspeciesmapper.netlify.app/Diomedea-antipodensis_2.html
# https://subspeciesmapper.netlify.app/Diomedea-antipodensis_4.html
# https://subspeciesmapper.netlify.app/Thalassarche-cauta_4.html
# https://subspeciesmapper.netlify.app/Thalassarche-cauta_3.html
# https://subspeciesmapper.netlify.app/Thalassarche-cauta_2.html
# https://subspeciesmapper.netlify.app/Thalassarche-melanophris_4.html
# https://subspeciesmapper.netlify.app/Thalassarche-melanophris_3.html
# https://subspeciesmapper.netlify.app/Thalassarche-melanophris_2.html
# https://subspeciesmapper.netlify.app/Oceanites-oceanicus_4.html
# ...
# https://subspeciesmapper.netlify.app/Geothlypis-trichas_2.html
# https://subspeciesmapper.netlify.app/Geothlypis-trichas_3.html
# https://subspeciesmapper.netlify.app/Setophaga-pitiayumi_4.html
# https://subspeciesmapper.netlify.app/Setophaga-pitiayumi_2.html
# https://subspeciesmapper.netlify.app/Setophaga-pitiayumi_3.html
# https://subspeciesmapper.netlify.app/Setophaga-petechia_3.html
# https://subspeciesmapper.netlify.app/Setophaga-petechia_2.html
# https://subspeciesmapper.netlify.app/Setophaga-petechia_4.html
# https://subspeciesmapper.netlify.app/Setophaga-palmarum_4.html
# https://subspeciesmapper.netlify.app/Setophaga-palmarum_2.html
# https://subspeciesmapper.netlify.app/Setophaga-palmarum_3.html
# https://subspeciesmapper.netlify.app/Setophaga-coronata_4.html
# https://subspeciesmapper.netlify.app/Setophaga-coronata_3.html
# https://subspeciesmapper.netlify.app/Setophaga-coronata_2.html
# https://subspeciesmapper.netlify.app/Setophaga-dominica_2.html
# https://subspeciesmapper.netlify.app/Setophaga-dominica_3.html
# https://subspeciesmapper.netlify.app/Setophaga-dominica_4.html
# https://subspeciesmapper.netlify.app/Basileuterus-rufifrons_3.html
# https://subspeciesmapper.netlify.app/Basileuterus-rufifrons_2.html
# https://subspeciesmapper.netlify.app/Basileuterus-rufifrons_4.html
# https://subspeciesmapper.netlify.app/Basileuterus-culicivorus_4.html
# https://subspeciesmapper.netlify.app/Basileuterus-culicivorus_3.html
# https://subspeciesmapper.netlify.app/Basileuterus-culicivorus_2.html
# https://subspeciesmapper.netlify.app/Basileuterus-tristriatus_3.html
# https://subspeciesmapper.netlify.app/Basileuterus-tristriatus_2.html
# https://subspeciesmapper.netlify.app/Basileuterus-tristriatus_4.html
# https://subspeciesmapper.netlify.app/Myiothlypis-luteoviridis_2.html
# https://subspeciesmapper.netlify.app/Myiothlypis-luteoviridis_3.html
# https://subspeciesmapper.netlify.app/Myiothlypis-luteoviridis_4.html
# https://subspeciesmapper.netlify.app/Myiothlypis-rivularis_2.html
# https://subspeciesmapper.netlify.app/Myiothlypis-rivularis_3.html
# https://subspeciesmapper.netlify.app/Myiothlypis-rivularis_4.html
# https://subspeciesmapper.netlify.app/Myiothlypis-bivittata_4.html
# https://subspeciesmapper.netlify.app/Myiothlypis-bivittata_2.html
# https://subspeciesmapper.netlify.app/Myiothlypis-bivittata_3.html
# https://subspeciesmapper.netlify.app/Cardellina-pusilla_2.html
# https://subspeciesmapper.netlify.app/Cardellina-pusilla_3.html
# https://subspeciesmapper.netlify.app/Cardellina-pusilla_4.html
# https://subspeciesmapper.netlify.app/Cardellina-rubra_2.html
# https://subspeciesmapper.netlify.app/Cardellina-rubra_3.html
# https://subspeciesmapper.netlify.app/Cardellina-rubra_4.html
# https://subspeciesmapper.netlify.app/Myioborus-ornatus_3.html
# https://subspeciesmapper.netlify.app/Myioborus-ornatus_2.html
# https://subspeciesmapper.netlify.app/Myioborus-ornatus_4.html
# https://subspeciesmapper.netlify.app/Piranga-flava_3.html
# https://subspeciesmapper.netlify.app/Piranga-flava_2.html
# https://subspeciesmapper.netlify.app/Piranga-flava_4.html
# https://subspeciesmapper.netlify.app/Habia-rubica_4.html
# https://subspeciesmapper.netlify.app/Habia-rubica_3.html
# https://subspeciesmapper.netlify.app/Habia-rubica_2.html
# https://subspeciesmapper.netlify.app/Driophlox-fuscicauda_4.html
# https://subspeciesmapper.netlify.app/Driophlox-fuscicauda_3.html
# https://subspeciesmapper.netlify.app/Driophlox-fuscicauda_2.html
# https://subspeciesmapper.netlify.app/Caryothraustes-poliogaster_2.html
# https://subspeciesmapper.netlify.app/Caryothraustes-poliogaster_3.html
# https://subspeciesmapper.netlify.app/Caryothraustes-poliogaster_4.html
# https://subspeciesmapper.netlify.app/Cardinalis-cardinalis_2.html
# https://subspeciesmapper.netlify.app/Cardinalis-cardinalis_3.html
# https://subspeciesmapper.netlify.app/Cardinalis-cardinalis_4.html
# https://subspeciesmapper.netlify.app/Pheucticus-chrysopeplus_4.html
# https://subspeciesmapper.netlify.app/Pheucticus-chrysopeplus_3.html
# https://subspeciesmapper.netlify.app/Pheucticus-chrysopeplus_2.html
# https://subspeciesmapper.netlify.app/Pheucticus-aureoventris_4.html
# https://subspeciesmapper.netlify.app/Pheucticus-aureoventris_3.html
# https://subspeciesmapper.netlify.app/Pheucticus-aureoventris_2.html
# https://subspeciesmapper.netlify.app/Granatellus-venustus_2.html
# https://subspeciesmapper.netlify.app/Granatellus-venustus_3.html
# https://subspeciesmapper.netlify.app/Granatellus-venustus_4.html
# https://subspeciesmapper.netlify.app/Granatellus-pelzelni_3.html
# https://subspeciesmapper.netlify.app/Granatellus-pelzelni_2.html
# https://subspeciesmapper.netlify.app/Granatellus-pelzelni_4.html
# https://subspeciesmapper.netlify.app/Amaurospiza-concolor_4.html
# https://subspeciesmapper.netlify.app/Amaurospiza-concolor_3.html
# https://subspeciesmapper.netlify.app/Amaurospiza-concolor_2.html
# https://subspeciesmapper.netlify.app/Cyanocompsa-parellina_3.html
# https://subspeciesmapper.netlify.app/Cyanocompsa-parellina_2.html
# https://subspeciesmapper.netlify.app/Cyanocompsa-parellina_4.html
# https://subspeciesmapper.netlify.app/Paroaria-gularis_2.html
# https://subspeciesmapper.netlify.app/Paroaria-gularis_3.html
# https://subspeciesmapper.netlify.app/Paroaria-gularis_4.html
# https://subspeciesmapper.netlify.app/Paroaria-baeri_4.html
# https://subspeciesmapper.netlify.app/Paroaria-baeri_3.html
# https://subspeciesmapper.netlify.app/Paroaria-baeri_2.html
# https://subspeciesmapper.netlify.app/Kleinothraupis-atropileus_4.html
# https://subspeciesmapper.netlify.app/Kleinothraupis-atropileus_2.html
# https://subspeciesmapper.netlify.app/Kleinothraupis-atropileus_3.html
# https://subspeciesmapper.netlify.app/Sphenopsis-melanotis_4.html
# https://subspeciesmapper.netlify.app/Sphenopsis-melanotis_2.html
# https://subspeciesmapper.netlify.app/Sphenopsis-melanotis_3.html
# https://subspeciesmapper.netlify.app/Thlypopsis-sordida_2.html
# https://subspeciesmapper.netlify.app/Thlypopsis-sordida_3.html
# https://subspeciesmapper.netlify.app/Thlypopsis-sordida_4.html
# https://subspeciesmapper.netlify.app/Thlypopsis-superciliaris_2.html
# https://subspeciesmapper.netlify.app/Thlypopsis-superciliaris_3.html
# https://subspeciesmapper.netlify.app/Thlypopsis-superciliaris_4.html
# https://subspeciesmapper.netlify.app/Microspingus-torquatus_4.html
# https://subspeciesmapper.netlify.app/Microspingus-torquatus_3.html
# https://subspeciesmapper.netlify.app/Microspingus-torquatus_2.html
# https://subspeciesmapper.netlify.app/Eucometis-penicillata_3.html
# https://subspeciesmapper.netlify.app/Eucometis-penicillata_2.html
# https://subspeciesmapper.netlify.app/Eucometis-penicillata_4.html
# https://subspeciesmapper.netlify.app/Loriotus-cristatus_4.html
# https://subspeciesmapper.netlify.app/Loriotus-cristatus_3.html
# https://subspeciesmapper.netlify.app/Loriotus-cristatus_2.html
# https://subspeciesmapper.netlify.app/Loriotus-luctuosus_2.html
# https://subspeciesmapper.netlify.app/Loriotus-luctuosus_3.html
# https://subspeciesmapper.netlify.app/Loriotus-luctuosus_4.html
# https://subspeciesmapper.netlify.app/Lanio-leucothorax_4.html
# https://subspeciesmapper.netlify.app/Lanio-leucothorax_2.html
# https://subspeciesmapper.netlify.app/Lanio-leucothorax_3.html
# https://subspeciesmapper.netlify.app/Ramphocelus-flammigerus_4.html
# https://subspeciesmapper.netlify.app/Ramphocelus-flammigerus_3.html
# https://subspeciesmapper.netlify.app/Ramphocelus-flammigerus_2.html
# https://subspeciesmapper.netlify.app/Ramphocelus-passerinii_4.html
# https://subspeciesmapper.netlify.app/Ramphocelus-passerinii_3.html
# https://subspeciesmapper.netlify.app/Ramphocelus-passerinii_2.html
# https://subspeciesmapper.netlify.app/Sporathraupis-cyanocephala_3.html
# https://subspeciesmapper.netlify.app/Sporathraupis-cyanocephala_2.html
# https://subspeciesmapper.netlify.app/Sporathraupis-cyanocephala_4.html
# https://subspeciesmapper.netlify.app/Cnemathraupis-eximia_3.html
# https://subspeciesmapper.netlify.app/Cnemathraupis-eximia_2.html
# https://subspeciesmapper.netlify.app/Cnemathraupis-eximia_4.html
# https://subspeciesmapper.netlify.app/Anisognathus-lacrymosus_4.html
# https://subspeciesmapper.netlify.app/Anisognathus-lacrymosus_3.html
# https://subspeciesmapper.netlify.app/Anisognathus-lacrymosus_2.html
# https://subspeciesmapper.netlify.app/Anisognathus-igniventris_4.html
# https://subspeciesmapper.netlify.app/Anisognathus-igniventris_3.html
# https://subspeciesmapper.netlify.app/Anisognathus-igniventris_2.html
# https://subspeciesmapper.netlify.app/Anisognathus-somptuosus_2.html
# https://subspeciesmapper.netlify.app/Anisognathus-somptuosus_3.html
# https://subspeciesmapper.netlify.app/Anisognathus-somptuosus_4.html
# https://subspeciesmapper.netlify.app/Dubusia-taeniata_2.html
# https://subspeciesmapper.netlify.app/Dubusia-taeniata_3.html
# https://subspeciesmapper.netlify.app/Dubusia-taeniata_4.html
# https://subspeciesmapper.netlify.app/Rauenia-bonariensis_3.html
# https://subspeciesmapper.netlify.app/Rauenia-bonariensis_2.html
# https://subspeciesmapper.netlify.app/Rauenia-bonariensis_4.html
# https://subspeciesmapper.netlify.app/Chlorochrysa-calliparaea_4.html
# https://subspeciesmapper.netlify.app/Chlorochrysa-calliparaea_3.html
# https://subspeciesmapper.netlify.app/Chlorochrysa-calliparaea_2.html
# https://subspeciesmapper.netlify.app/Thraupis-episcopus_3.html
# https://subspeciesmapper.netlify.app/Thraupis-episcopus_2.html
# https://subspeciesmapper.netlify.app/Thraupis-episcopus_4.html
# https://subspeciesmapper.netlify.app/Thraupis-palmarum_2.html
# https://subspeciesmapper.netlify.app/Thraupis-palmarum_3.html
# https://subspeciesmapper.netlify.app/Thraupis-palmarum_4.html
# https://subspeciesmapper.netlify.app/Chalcothraupis-ruficervix_2.html
# https://subspeciesmapper.netlify.app/Chalcothraupis-ruficervix_3.html
# https://subspeciesmapper.netlify.app/Chalcothraupis-ruficervix_4.html
# https://subspeciesmapper.netlify.app/Stilpnia-cyanoptera_4.html
# https://subspeciesmapper.netlify.app/Stilpnia-cyanoptera_3.html
# https://subspeciesmapper.netlify.app/Stilpnia-cyanoptera_2.html
# https://subspeciesmapper.netlify.app/Stilpnia-cayana_4.html
# https://subspeciesmapper.netlify.app/Stilpnia-cayana_2.html
# https://subspeciesmapper.netlify.app/Stilpnia-cayana_3.html
# https://subspeciesmapper.netlify.app/Stilpnia-cucullata_4.html
# https://subspeciesmapper.netlify.app/Stilpnia-cucullata_2.html
# https://subspeciesmapper.netlify.app/Stilpnia-cucullata_3.html
# https://subspeciesmapper.netlify.app/Tangara-vassorii_3.html
# https://subspeciesmapper.netlify.app/Tangara-vassorii_2.html
# https://subspeciesmapper.netlify.app/Tangara-vassorii_4.html
# https://subspeciesmapper.netlify.app/Tangara-velia_2.html
# https://subspeciesmapper.netlify.app/Tangara-velia_3.html
# https://subspeciesmapper.netlify.app/Tangara-velia_4.html
# https://subspeciesmapper.netlify.app/Tangara-gyrola_3.html
# https://subspeciesmapper.netlify.app/Tangara-gyrola_2.html
# https://subspeciesmapper.netlify.app/Tangara-gyrola_4.html
# https://subspeciesmapper.netlify.app/Tangara-parzudakii_2.html
# https://subspeciesmapper.netlify.app/Tangara-parzudakii_3.html
# https://subspeciesmapper.netlify.app/Tangara-parzudakii_4.html
# https://subspeciesmapper.netlify.app/Tangara-arthus_4.html
# https://subspeciesmapper.netlify.app/Tangara-arthus_3.html
# https://subspeciesmapper.netlify.app/Tangara-arthus_2.html
# https://subspeciesmapper.netlify.app/Dacnis-lineata_3.html
# https://subspeciesmapper.netlify.app/Dacnis-lineata_2.html
# https://subspeciesmapper.netlify.app/Dacnis-lineata_4.html
# https://subspeciesmapper.netlify.app/Conirostrum-albifrons_3.html
# https://subspeciesmapper.netlify.app/Conirostrum-albifrons_2.html
# https://subspeciesmapper.netlify.app/Conirostrum-albifrons_4.html
# https://subspeciesmapper.netlify.app/Conirostrum-cinereum_2.html
# https://subspeciesmapper.netlify.app/Conirostrum-cinereum_3.html
# https://subspeciesmapper.netlify.app/Conirostrum-cinereum_4.html
# https://subspeciesmapper.netlify.app/Diglossa-mystacalis_3.html
# https://subspeciesmapper.netlify.app/Diglossa-mystacalis_2.html
# https://subspeciesmapper.netlify.app/Diglossa-mystacalis_4.html
# https://subspeciesmapper.netlify.app/Diglossa-brunneiventris_4.html
# https://subspeciesmapper.netlify.app/Diglossa-brunneiventris_3.html
# https://subspeciesmapper.netlify.app/Diglossa-brunneiventris_2.html
# https://subspeciesmapper.netlify.app/Diglossa-cyanea_4.html
# https://subspeciesmapper.netlify.app/Diglossa-cyanea_2.html
# https://subspeciesmapper.netlify.app/Diglossa-cyanea_3.html
# https://subspeciesmapper.netlify.app/Phrygilus-gayi_3.html
# https://subspeciesmapper.netlify.app/Phrygilus-gayi_2.html
# https://subspeciesmapper.netlify.app/Phrygilus-gayi_4.html
# https://subspeciesmapper.netlify.app/Melanodera-melanodera_4.html
# https://subspeciesmapper.netlify.app/Melanodera-melanodera_3.html
# https://subspeciesmapper.netlify.app/Melanodera-melanodera_2.html
# https://subspeciesmapper.netlify.app/Melanodera-xanthogramma_4.html
# https://subspeciesmapper.netlify.app/Melanodera-xanthogramma_3.html
# https://subspeciesmapper.netlify.app/Melanodera-xanthogramma_2.html
# https://subspeciesmapper.netlify.app/Xenodacnis-parina_4.html
# https://subspeciesmapper.netlify.app/Xenodacnis-parina_3.html
# https://subspeciesmapper.netlify.app/Xenodacnis-parina_2.html
# https://subspeciesmapper.netlify.app/Geospizopsis-unicolor_4.html
# https://subspeciesmapper.netlify.app/Geospizopsis-unicolor_2.html
# https://subspeciesmapper.netlify.app/Geospizopsis-unicolor_3.html
# https://subspeciesmapper.netlify.app/Nesospiza-acunhae_4.html
# https://subspeciesmapper.netlify.app/Nesospiza-acunhae_2.html
# https://subspeciesmapper.netlify.app/Nesospiza-acunhae_3.html
# https://subspeciesmapper.netlify.app/Rhopospina-fruticeti_2.html
# https://subspeciesmapper.netlify.app/Rhopospina-fruticeti_3.html
# https://subspeciesmapper.netlify.app/Rhopospina-fruticeti_4.html
# https://subspeciesmapper.netlify.app/Cnemoscopus-rubrirostris_4.html
# https://subspeciesmapper.netlify.app/Cnemoscopus-rubrirostris_3.html
# https://subspeciesmapper.netlify.app/Cnemoscopus-rubrirostris_2.html
# https://subspeciesmapper.netlify.app/Sicalis-flaveola_2.html
# https://subspeciesmapper.netlify.app/Sicalis-flaveola_3.html
# https://subspeciesmapper.netlify.app/Sicalis-flaveola_4.html
# https://subspeciesmapper.netlify.app/Sicalis-luteola_3.html
# https://subspeciesmapper.netlify.app/Sicalis-luteola_2.html
# https://subspeciesmapper.netlify.app/Sicalis-luteola_4.html
# https://subspeciesmapper.netlify.app/Emberizoides-herbicola_3.html
# https://subspeciesmapper.netlify.app/Emberizoides-herbicola_2.html
# https://subspeciesmapper.netlify.app/Emberizoides-herbicola_4.html
# https://subspeciesmapper.netlify.app/Embernagra-platensis_4.html
# https://subspeciesmapper.netlify.app/Embernagra-platensis_3.html
# https://subspeciesmapper.netlify.app/Embernagra-platensis_2.html
# https://subspeciesmapper.netlify.app/Sporophila-leucoptera_2.html
# https://subspeciesmapper.netlify.app/Sporophila-leucoptera_3.html
# https://subspeciesmapper.netlify.app/Sporophila-leucoptera_4.html
# https://subspeciesmapper.netlify.app/Sporophila-corvina_4.html
# https://subspeciesmapper.netlify.app/Sporophila-corvina_3.html
# https://subspeciesmapper.netlify.app/Sporophila-corvina_2.html
# https://subspeciesmapper.netlify.app/Sporophila-americana_4.html
# https://subspeciesmapper.netlify.app/Sporophila-americana_3.html
# https://subspeciesmapper.netlify.app/Sporophila-americana_2.html
# https://subspeciesmapper.netlify.app/Sporophila-morelleti_4.html
# https://subspeciesmapper.netlify.app/Sporophila-morelleti_3.html
# https://subspeciesmapper.netlify.app/Sporophila-morelleti_2.html
# https://subspeciesmapper.netlify.app/Catamenia-homochroa_4.html
# https://subspeciesmapper.netlify.app/Catamenia-homochroa_3.html
# https://subspeciesmapper.netlify.app/Catamenia-homochroa_2.html
# https://subspeciesmapper.netlify.app/Coereba-flaveola_2.html
# https://subspeciesmapper.netlify.app/Coereba-flaveola_3.html
# https://subspeciesmapper.netlify.app/Coereba-flaveola_4.html
# https://subspeciesmapper.netlify.app/Camarhynchus-pallidus_3.html
# https://subspeciesmapper.netlify.app/Camarhynchus-pallidus_2.html
# https://subspeciesmapper.netlify.app/Camarhynchus-pallidus_4.html
